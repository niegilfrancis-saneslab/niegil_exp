# %% [markdown]
# ### Note: Please ensure that this notebook is run in the daq environment

# %%
import glob
import os
import tqdm
from collections import defaultdict
import re
import numpy as np
import pandas as pd
from scipy.io import wavfile
# from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.video.io.VideoFileClip import VideoFileClip
from datetime import datetime, timedelta
import copy

# %%
def seconds_to_hms(seconds):
    # Calculate hours, minutes, and seconds
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    # Format the time in HH:MM:SS
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}.{int(remainder%1*1000):03}"

# %%
from moviepy.tools import subprocess_call
from moviepy.config import get_setting

# def ffmpeg_extract_subclip(filename, t1, t2, targetname=None):
def ffmpeg_extract_subclip(filename, start_frame, end_frame, targetname=None):
    """ Makes a new video file playing video file ``filename`` between
    the times ``t1`` and ``t2``. """
    # !ffmpeg -i {filename} -ss {seconds_to_hms(t1)} -to {seconds_to_hms(t2)} -c copy {targetname}
    tmp_str = f"between(n\,{start_frame}\,{end_frame}),setpts=PTS-STARTPTS"
    # !ffmpeg -i {filename} -vf select={tmp_str} -c:v libx264 -crf 0 {targetname}

# %%
experiment_no = 311
no_channels = 11
camera_fps = 30
# camera_corrected_sample_time = 0.03338542
file_length = 120 # in seconds (120 sec - 2 mins)
sampling_rate = 125000
# nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
video_folder = "D:/big_setup/experiment_{}/videos/".format(experiment_no)

# %%
# Deleting the trunc files if it is already present
trunc_files = glob.glob(nidaq_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i) 

trunc_files = glob.glob(video_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i)

# %%
nidaq_files = glob.glob(nidaq_folder+"*")
video_files = glob.glob(video_folder+"*")

# %%
# Creating separate folders for the concatenated data
path_concat = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/temp/".format(experiment_no)

try:
    os.makedirs(path_concat)
except:
    pass

# %%
path_final = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/".format(experiment_no)

# %%
# Functions to sort file names correctly
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
nidaq_files.sort(key=natural_keys)
video_files.sort(key=natural_keys)

# %%
nidaq_files = [i.replace("\\",'/') for i in nidaq_files]
video_files = [i.replace("\\",'/') for i in video_files]

# %% [markdown]
# ### For Videos

# %%
# Getting the camera names
temp_cam_name = []
for i in video_files:
    temp_cam_name.append(i.split("/")[-1].split("-")[0])
camera_names = list(set(temp_cam_name))
print(camera_names)
# Out:
# ['gily_center']

# %%
# Creating a dictionary of all videos of a single camera
video_by_camera = defaultdict(lambda:[])
for idx,name in enumerate(temp_cam_name):
    video_by_camera[name].append(video_files[idx])

# %%
cam_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")

# %%
file_breaks  = np.arange(0,cam_clk_data.tail(1).index[0]/camera_fps,file_length)
last_break = cam_clk_data.tail(1).index[0]
timestamp_idx = []
for val in file_breaks:
    timestamp_idx.append((np.abs(cam_clk_data[f'concat_{camera_names[0]}_time_from_vid_start'] - val)).argmin())

# %%
if timestamp_idx[-1] != last_break:
    timestamp_idx.append(last_break)

# %% [markdown]
# ### Assumes
# - 5 min original videos and shorter concatenated videos
# - concatenation starts from 0.0 of first video for each camera
# - all videos are recorded properly

# %%
vals = []
for cam in camera_names:
    file_concat_index = 0 
    no_videos = len(video_by_camera[cam])
    id = 0
    
    temp = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_file_name'].split('\\')
    prev_vid_name = temp[0]+'/'+temp[1]
    # prev_break_time = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_time_from_vid_start']
    prev_break_frame = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_frame_idx']
    prev_file_break = timestamp_idx[0]

    for file_break in timestamp_idx[1:]:

            #--------------------------------------- edited -----------------------------------------------

            temp = cam_clk_data.iloc[file_break][f'{cam}_file_name'].split('\\')
            vid_name = temp[0]+'/'+temp[1]
            # break_time = cam_clk_data.iloc[file_break][f'{cam}_time_from_vid_start']
            break_frame = cam_clk_data.iloc[file_break][f'{cam}_frame_idx']
            str_1 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"video_{cam}_{str_1}.txt"

            if prev_vid_name != vid_name: # when we reach the end of a saved file and start a new one

                with VideoFileClip(prev_vid_name) as video:
                    # end_time = video.duration
                    end_frame = video.reader.nframes
                    
                    # vals.append([end_time,prev_break_time])
                    # if end_time-prev_break_time > 1:
                    if end_frame-prev_break_frame > 1:
                        tmp = cam_clk_data.iloc[prev_file_break][f'{cam}_file_name'].split('\\')
                        target_file = tmp[0]+"/"+tmp[1].split(".")[0]+f"_trunc_{id}.mp4"      
                        # ffmpeg_extract_subclip(prev_vid_name, prev_break_time, end_time, targetname=target_file)
                        ffmpeg_extract_subclip(prev_vid_name, prev_break_frame, end_frame-1, targetname=target_file)
                
                        f = open(filename_txt, 'a')
                        f.write("file \'{}\'\n".format(target_file))
                        f.close()
                    
                    # prev_break_time = 0.0
                    prev_break_frame = 0
                    id = 0
                    
            target_file = temp[0]+"/"+temp[1].split(".")[0]+f"_trunc_{id}.mp4"
            # ffmpeg_extract_subclip(vid_name, prev_break_time, break_time, targetname=target_file)
            ffmpeg_extract_subclip(vid_name, prev_break_frame, break_frame-1, targetname=target_file)

            f = open(filename_txt, 'a')
            f.write("file \'{}\'\n".format(target_file))
            f.close()
            
            # prev_break_time = copy.deepcopy(break_time)
            prev_break_frame =  copy.deepcopy(break_frame)
            id+=1
            file_concat_index+=1
            prev_vid_name = copy.deepcopy(vid_name)
            prev_file_break = copy.deepcopy(file_break)
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_311/videos/gily_center-20250918T155350-155851.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 3145 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 3142 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 00000211AFDB0FC0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 00000211AFDB0FC0] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 00000211AFDB0FC0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_311/videos/gily_center-20250918T155350-155851_trunc_0.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=
iB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005776%
# frame= 3600 fps=256 q=-1.0 Lsize=  352370KiB time=00:01:59.99 bitrate=24055.4kbits/s speed=8.53x elapsed=0:00:14.05
# [libx264 @ 00000286C07CEB40] frame I:15    Avg QP: 0.00  size:346699
# [libx264 @ 00000286C07CEB40] frame P:3585  Avg QP: 0.00  size: 99193
# [libx264 @ 00000286C07CEB40] mb I  I16..4: 38.2% 28.4% 33.4%
# [libx264 @ 00000286C07CEB40] mb P  I16..4:  6.2%  5.5%  0.9%  P16..4: 47.4%  4.5% 10.9%  0.0%  0.0%    skip:24.7%
# [libx264 @ 00000286C07CEB40] 8x8 transform intra:43.0% inter:65.9%
# [libx264 @ 00000286C07CEB40] coded y,uvDC,uvAC intra: 85.7% 0.0% 0.0% inter: 38.9% 0.0% 0.0%
# [libx264 @ 00000286C07CEB40] i16 v,h,dc,p: 71% 29%  1%  0%
# [libx264 @ 00000286C07CEB40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 31% 27%  2%  3%  1%  1%  1%  1%
# [libx264 @ 00000286C07CEB40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 40%  3%  2%  4%  2%  3%  1%  2%
# [libx264 @ 00000286C07CEB40] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 00000286C07CEB40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 00000286C07CEB40] ref P L0: 92.5%  5.1%  1.9%  0.5%
# [libx264 @ 00000286C07CEB40] kb/s:24053.95
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_311/videos/gily_center-20250918T155350-155851.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 3145 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 3142 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0000027BC0964900] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0000027BC0964900] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0000027BC0964900] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_311/videos/gily_center-20250918T155350-155851_trunc_2.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 24 q=0.0 size=    5376KiB time=00:00:01.99 bitrate=22020.5kbits/s speed=0.786x elapsed=0:00:02.54
# frame=  170 fps= 56 q=0.0 size=   16384KiB time=00:00:05.66 bitrate=23685.8kbits/s speed=1.85x elapsed=0:00:03.05
# frame=  280 fps= 78 q=0.0 size=   27904KiB time=00:00:09.33 bitrate=24492.0kbits/s speed=2.61x elapsed=0:00:03.57
# frame=  389 fps= 96 q=0.0 size=   38912KiB time=00:00:12.96 bitrate=24583.9kbits/s speed=3.18x elapsed=0:00:04.07
# frame=  491 fps=107 q=0.0 size=   49408KiB time=00:00:16.36 bitrate=24730.4kbits/s speed=3.57x elapsed=0:00:04.58
# frame=  622 fps=122 q=0.0 size=   62976KiB time=00:00:20.73 bitrate=24882.9kbits/s speed=4.07x elapsed=0:00:05.09
# frame=  741 fps=132 q=0.0 size=   75008KiB time=00:00:24.69 bitrate=24877.4kbits/s speed= 4.4x elapsed=0:00:05.60
# frame=  870 fps=142 q=0.0 size=   88576KiB time=00:00:28.99 bitrate=25021.5kbits/s speed=4.74x elapsed=0:00:06.12
# frame=  987 fps=149 q=0.0 size=  100352KiB time=00:00:32.89 bitrate=24987.6kbits/s speed=4.96x elapsed=0:00:06.63
# frame= 1111 fps=155 q=0.0 size=  113408KiB time=00:00:37.03 bitrate=25086.8kbits/s speed=5.18x elapsed=0:00:07.14
# frame= 1231 fps=161 q=0.0 size=  125952KiB time=00:00:41.03 bitrate=25145.6kbits/s speed=5.36x elapsed=0:00:07.66
# frame= 1358 fps=166 q=0.0 size=  139008KiB time=00:00:45.26 bitrate=25156.8kbits/s speed=5.54x elapsed=0:00:08.17
# frame= 1470 fps=169 q=0.0 size=  149504KiB time=00:00:48.99 bitrate=24994.9kbits/s speed=5.64x elapsed=0:00:08.68
# frame= 1600 fps=174 q=0.0 size=  162048KiB time=00:00:53.33 bitrate=24890.8kbits/s speed= 5.8x elapsed=0:00:09.19
# frame= 1724 fps=177 q=0.0 size=  173568KiB time=00:00:57.46 bitrate=24742.8kbits/s speed=5.92x elapsed=0:00:09.71
# [out#0/mp4 @ 0000027BBC4A9280] video:183915KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.
# frame= 3126 fps=218 q=0.0 size=  291584KiB time=00:01:44.19 bitrate=22924.0kbits/s speed=7.28x elapsed=0:00:14.31
# frame= 3244 fps=219 q=0.0 size=  302336KiB time=00:01:48.13 bitrate=22904.7kbits/s speed= 7.3x elapsed=0:00:14.81
# frame= 3385 fps=221 q=0.0 size=  315648KiB time=00:01:52.83 bitrate=22917.1kbits/s speed=7.36x elapsed=0:00:15.32
# frame= 3513 fps=222 q=0.0 size=  327936KiB time=00:01:57.09 bitrate=22941.8kbits/s speed=7.39x elapsed=0:00:15.84
# [out#0/mp4 @ 000002BDA69978C0] video:335832KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.006059%
# frame= 3600 fps=223 q=-1.0 Lsize=  335852KiB time=00:01:59.99 bitrate=22927.7kbits/s speed=7.42x elapsed=0:00:16.17
# [libx264 @ 000002BDA69E79C0] frame I:15    Avg QP: 0.00  size:344818
# [libx264 @ 000002BDA69E79C0] frame P:3585  Avg QP: 0.00  size: 94482
# [libx264 @ 000002BDA69E79C0] mb I  I16..4: 38.6% 28.1% 33.3%
# [libx264 @ 000002BDA69E79C0] mb P  I16..4:  6.0%  5.3%  0.6%  P16..4: 47.6%  4.3% 10.7%  0.0%  0.0%    skip:25.5%
# [libx264 @ 000002BDA69E79C0] 8x8 transform intra:43.9% inter:66.0%
# [libx264 @ 000002BDA69E79C0] coded y,uvDC,uvAC intra: 85.3% 0.0% 0.0% inter: 38.2% 0.0% 0.0%
# [libx264 @ 000002BDA69E79C0] i16 v,h,dc,p: 71% 28%  1%  0%
# [libx264 @ 000002BDA69E79C0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 30% 27%  2%  3%  1%  1%  1%  1%
# [libx264 @ 000002BDA69E79C0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 40%  3%  1%  3%  1%  2%  1%  1%
# [libx264 @ 000002BDA69E79C0] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 000002BDA69E79C0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000002BDA69E79C0] ref P L0: 92.7%  4.8%  1.9%  0.5%
# [libx264 @ 000002BDA69E79C0] kb/s:22926.31
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_311/videos/gily_center-20250918T155851-160352.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 2866 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 2863 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 00000262F52D8200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 00000262F52D8200] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 00000262F52D8200] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_311/videos/gily_center-20250918T155851-160352_trunc_3.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   30 fps=9.8 q=-1.0 size=    2560KiB time=00:00:00.99 bitrate=20972.1kbits/s speed=0.326x elapsed=0:00:03.06
# [out#0/mp4 @ 00000262F52AEC40] video:5584KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.020286%
# frame=   60 fps= 19 q=-1.0 Lsize=    5585KiB time=00:00:01.99 bitrate=22878.1kbits/s speed=0.633x elapsed=0:00:03.15
# [libx264 @ 00000262F52D8200] frame I:1     Avg QP: 0.00  size:281171
# [libx264 @ 00000262F52D8200] frame P:59    Avg QP: 0.00  size: 92146
# [libx264 @ 00000262F52D8200] mb I  I16..4: 36.2% 37.5% 26.3%
# [libx264 @ 00000262F52D8200] mb P  I16..4:  5.6%  4.7%  0.3%  P16..4: 48.4%  4.4% 10.9%  0.0%  0.0%    skip:25.6%
# [libx264 @ 00000262F52D8200] 8x8 transform intra:43.1% inter:66.0%
# [libx264 @ 00000262F52D8200] coded y,uvDC,uvAC intra: 85.4% 0.0% 0.0% inter: 38.3% 0.0% 0.0%
# ...
# [libx264 @ 0000012C14DBEB80] kb/s:24803.07
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment
# frame= 2533 fps=237 q=0.0 size=  244736KiB time=00:01:24.43 bitrate=23745.3kbits/s speed= 7.9x elapsed=0:00:10.69
# frame= 2665 fps=238 q=0.0 size=  257024KiB time=00:01:28.83 bitrate=23702.4kbits/s speed=7.93x elapsed=0:00:11.20
# frame= 2797 fps=239 q=0.0 size=  269568KiB time=00:01:33.23 bitrate=23686.0kbits/s speed=7.95x elapsed=0:00:11.72
# frame= 2930 fps=239 q=0.0 size=  281856KiB time=00:01:37.66 bitrate=23641.5kbits/s speed=7.98x elapsed=0:00:12.23
# frame= 3060 fps=240 q=0.0 size=  293888KiB time=00:01:41.99 bitrate=23603.5kbits/s speed=   8x elapsed=0:00:12.74
# frame= 3182 fps=240 q=0.0 size=  305152KiB time=00:01:46.06 bitrate=23568.5kbits/s speed=8.01x elapsed=0:00:13.24
# frame= 3314 fps=241 q=0.0 size=  317696KiB time=00:01:50.46 bitrate=23560.0kbits/s speed=8.03x elapsed=0:00:13.74
# frame= 3444 fps=242 q=0.0 size=  329728KiB time=00:01:54.79 bitrate=23529.3kbits/s speed=8.05x elapsed=0:00:14.26
# frame= 3563 fps=241 q=0.0 size=  340992KiB time=00:01:58.76 bitrate=23520.4kbits/s speed=8.04x elapsed=0:00:14.77
# frame= 3563 fps=233 q=0.0 size=  340992KiB time=00:01:58.76 bitrate=23520.4kbits/s speed=7.77x elapsed=0:00:15.28
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000002463B95FC40] Packet corrupt (stream = 0, dts = 2610307230).
# [h264 @ 000002463B9C8200] Invalid NAL unit size (15216 > 3310).
# [h264 @ 000002463B9C8200] missing picture in access unit with size 3314
# [in#0/mov,mp4,m4a,3gp,3g2,mj2 @ 000002463B95FB00] corrupt input packet in stream 0
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000002463B95FC40] stream 0, offset 0x5adf8fe: partial file
# [h264 @ 000002463F89A700] Invalid NAL unit size (15216 > 3310).
# [h264 @ 000002463F89A700] Error splitting the input into NAL units.
# [vist#0:0/h264 @ 000002463F89ED80] [dec:h264 @ 000002463B9859C0] Decoding error: Invalid data found when processing input
# [out#0/mp4 @ 000002463B950A40] video:344591KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005892%
# frame= 3600 fps=231 q=-1.0 Lsize=  344611KiB time=00:01:59.99 bitrate=23525.7kbits/s speed= 7.7x elapsed=0:00:15.58
# [libx264 @ 000002463B9C7780] frame I:15    Avg QP: 0.00  size:346306
# [libx264 @ 000002463B9C7780] frame P:3585  Avg QP: 0.00  size: 96978
# [libx264 @ 000002463B9C7780] mb I  I16..4: 38.6% 27.9% 33.5%
# [libx264 @ 000002463B9C7780] mb P  I16..4:  6.1%  5.3%  0.8%  P16..4: 47.6%  4.4% 10.8%  0.0%  0.0%    skip:25.1%
# [libx264 @ 000002463B9C7780] 8x8 transform intra:43.3% inter:65.8%
# [libx264 @ 000002463B9C7780] coded y,uvDC,uvAC intra: 85.6% 0.0% 0.0% inter: 38.5% 0.0% 0.0%
# [libx264 @ 000002463B9C7780] i16 v,h,dc,p: 71% 28%  1%  0%
# [libx264 @ 000002463B9C7780] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 31% 27%  2%  3%  1%  1%  1%  1%
# [libx264 @ 000002463B9C7780] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 39%  3%  2%  4%  2%  2%  1%  1%
# [libx264 @ 000002463B9C7780] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 000002463B9C7780] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000002463B9C7780] ref P L0: 92.6%  5.0%  1.9%  0.5%
# [libx264 @ 000002463B9C7780] kb/s:23524.25
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_311/videos/gily_center-20250918T160853-161314.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:04:22.00, start: 0.000000, bitrate: 2909 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 2914 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 000002A1D3491880] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000002A1D3491880] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 000002A1D3491880] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_311/videos/gily_center-20250918T160853-161314_trunc_2.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   77 fps= 38 q=0.0 size=    7168KiB time=00:00:02.56 bitrate=22878.4kbits/s speed=1.26x elapsed=0:00:02.04
# frame=  206 fps= 81 q=0.0 size=   18944KiB time=00:00:06.86 bitrate=22600.7kbits/s speed=2.69x elapsed=0:00:02.55
# frame=  336 fps=110 q=0.0 size=   31488KiB time=00:00:11.19 bitrate=23031.5kbits/s speed=3.65x elapsed=0:00:03.06
# frame=  463 fps=129 q=0.0 size=   43264KiB time=00:00:15.43 bitrate=22964.7kbits/s speed=4.31x elapsed=0:00:03.58
# frame=  581 fps=142 q=0.0 size=   54528KiB time=00:00:19.36 bitrate=23065.3kbits/s speed=4.73x elapsed=0:00:04.09
# frame=  720 fps=156 q=0.0 size=   67072KiB time=00:00:23.99 bitrate=22894.2kbits/s speed=5.21x elapsed=0:00:04.61
# frame=  849 fps=166 q=0.0 size=   79360KiB time=00:00:28.29 bitrate=22972.6kbits/s speed=5.52x elapsed=0:00:05.12
# frame=  975 fps=173 q=0.0 size=   91136KiB time=00:00:32.46 bitrate=22995.7kbits/s speed=5.76x elapsed=0:00:05.63
# frame= 1110 fps=180 q=0.0 size=  103424KiB time=00:00:36.99 bitrate=22898.9kbits/s speed=6.01x elapsed=0:00:06.15
# frame= 1237 fps=186 q=0.0 size=  115456KiB time=00:00:41.23 bitrate=22938.4kbits/s speed=6.18x elapsed=0:00:06.66
# frame= 1380 fps=193 q=0.0 size=  128768KiB time=00:00:45.99 bitrate=22932.1kbits/s speed=6.42x elapsed=0:00:07.16
# frame= 1524 fps=198 q=0.0 size=  142080KiB time=00:00:50.79 bitrate=22912.0kbits/s speed=6.61x elapsed=0:00:07.68
# frame= 1641 fps=200 q=0.0 size=  153088KiB time=00:00:54.69 bitrate=22927.1kbits/s speed=6.68x elapsed=0:00:08.19
# frame= 1775 fps=204 q=0.0 size=  165632KiB time=00:00:59.16 bitrate=22933.0kbits/s speed= 6.8x elapsed=0:00:08.70
# frame= 1895 fps=206 q=0.0 size=  176896KiB time=00:01:03.16 bitrate=22941.6kbits/s speed=6.86x elapsed=0:00:09.20
# frame= 2035 fps=209 q=0.0 size=  189696KiB time=00:01:07.83 bitrate=22909.2kbits/s speed=6.98x elapsed=0:00:09.72
# frame= 2144 fps=209 q=0.0 size=  199936KiB time=00:01:11.73 bitrate=22833.1kbits/s speed=7.01x elapsed=0:00:10.23
# frame= 2288 fps=213 q=0.0 size=  213504KiB time=00:01:16.26 bitrate=22933.3kbits/s speed= 7.1x elapsed=0:00:10.74
# frame= 2427 fps=216 q=0.0 size=  226048KiB time=00:01:20.89 bitrate=22890.0kbits/s speed=7.18x elapsed=0:00:11.26
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000002A1CEF7C6C0] Packet corrupt (stream = 0, dts = 2610307230).
# [h264 @ 000002A1D2DEE980] Invalid NAL unit size (15216 > 3310).
# [h264 @ 000002A1D2DEE980] missing picture in access unit with size 3314
# [in#0/mov,mp4,m4a,3gp,3g2,mj2 @ 000002A1CEF7C540] corrupt input packet in stream 0
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000002A1CEF7C6C0] stream 0, offset 0x5adf8fe: partial file
# [h264 @ 000002A1D2F61C00] Invalid NAL unit size (15216 > 3310).
# [h264 @ 000002A1D2F61C00] Error splitting the input into NAL units.
# [vist#0:0/h264 @ 000002A1D2D95580] [dec:h264 @ 000002A1CEFA0B00] Decoding error: Invalid data found when processing input
# [out#0/mp4 @ 000002A1CEF79CC0] video:231945KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.006184%
# frame= 2490 fps=217 q=-1.0 Lsize=  231959KiB time=00:01:22.99 bitrate=22894.3kbits/s speed=7.22x elapsed=0:00:11.48
# [libx264 @ 000002A1D3491880] frame I:10    Avg QP: 0.00  size:339513
# [libx264 @ 000002A1D3491880] frame P:2480  Avg QP: 0.00  size: 94402
# [libx264 @ 000002A1D3491880] mb I  I16..4: 38.4% 28.9% 32.7%
# [libx264 @ 000002A1D3491880] mb P  I16..4:  5.9%  5.2%  0.6%  P16..4: 47.6%  4.3% 10.6%  0.0%  0.0%    skip:25.7%
# [libx264 @ 000002A1D3491880] 8x8 transform intra:43.9% inter:65.8%
# [libx264 @ 000002A1D3491880] coded y,uvDC,uvAC intra: 85.3% 0.0% 0.0% inter: 38.1% 0.0% 0.0%
# [libx264 @ 000002A1D3491880] i16 v,h,dc,p: 71% 28%  1%  0%
# [libx264 @ 000002A1D3491880] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 30% 27%  2%  3%  1%  1%  1%  1%
# [libx264 @ 000002A1D3491880] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 40%  3%  1%  4%  1%  2%  1%  1%
# [libx264 @ 000002A1D3491880] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 000002A1D3491880] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000002A1D3491880] ref P L0: 92.8%  4.8%  1.9%  0.5%
# [libx264 @ 000002A1D3491880] kb/s:22892.88

# %% [markdown]
# ### For NIDAQ

# %%
# Reading the timestamps data for the camera clock channel 
audio_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")
audio_start_rec_idx = int(cam_clk_data["clk_ch_file_name"][0].split("\\")[1].split("_")[2])
audio_stop_rec_idx = int(cam_clk_data["clk_ch_file_name"].iloc[-1].split("\\")[1].split("_")[2])
start_sample_index =  int(cam_clk_data["clk_ch_sample_idx"][0])
end_sample_index =  int(cam_clk_data["clk_ch_sample_idx"].iloc[-1])

# %%
# Concatenating the microphone channels
for ch_no in range(no_channels):
    file_concat_index = 0 
    id = 0

    prev_ch_name = "_".join(audio_clk_data.iloc[timestamp_idx[0]][f'clk_ch_file_name'].split("_")[:-1])+f"_{ch_no}.wav"
    prev_break_idx = audio_clk_data.iloc[timestamp_idx[0]][f'clk_ch_sample_idx']


    for file_break in tqdm.tqdm(timestamp_idx[1:]):

            #--------------------------------------- edited -----------------------------------------------

            ch_name = "_".join(audio_clk_data.iloc[file_break][f'clk_ch_file_name'].split("_")[:-1])+f"_{ch_no}.wav"
            break_idx = audio_clk_data.iloc[file_break][f'clk_ch_sample_idx']
            str_1 = "%02d"%(ch_no)
            str_2 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"channel_{str_1}_file_{str_2}.txt"

            if prev_ch_name != ch_name: # when we reach the end of a saved file and start a new one
                    if prev_break_idx < (sampling_rate*300)-1000:
                        target_file = prev_ch_name.split(".")[0]+f"_trunc_{id}.wav"   

                        # Loading the file
                        sampling_rate,ch = wavfile.read(prev_ch_name)
                        ch = ch[prev_break_idx:]
                        
                        wavfile.write(target_file,sampling_rate,ch)
                
                        f = open(filename_txt, 'a')
                        f.write("file \'{}\'\n".format(target_file))
                        f.close()
                    
                    prev_break_idx = 0
                    id = 0
                    
            target_file = ch_name.split(".")[0]+f"_trunc_{id}.wav"

            # Loading the file
            sampling_rate,ch = wavfile.read(ch_name)
            ch = ch[prev_break_idx:break_idx]
                        
            wavfile.write(target_file,sampling_rate,ch)
                
            f = open(filename_txt, 'a')
            f.write("file \'{}\'\n".format(target_file))
            f.close()
                    

            
            prev_break_idx = copy.deepcopy(break_idx)
            id+=1
            file_concat_index+=1
            prev_ch_name = copy.deepcopy(ch_name)
# Out:
# 100%|██████████| 68/68 [00:52<00:00,  1.29it/s]
# 100%|██████████| 68/68 [00:53<00:00,  1.28it/s]
# 100%|██████████| 68/68 [00:51<00:00,  1.32it/s]
# 100%|██████████| 68/68 [00:51<00:00,  1.33it/s]
# 100%|██████████| 68/68 [00:48<00:00,  1.39it/s]
# 100%|██████████| 68/68 [00:38<00:00,  1.79it/s]
# 100%|██████████| 68/68 [00:41<00:00,  1.63it/s]
# 100%|██████████| 68/68 [00:38<00:00,  1.76it/s]
# 100%|██████████| 68/68 [00:38<00:00,  1.75it/s]
# 100%|██████████| 68/68 [00:37<00:00,  1.81it/s]
# 100%|██████████| 68/68 [00:38<00:00,  1.79it/s]

# %% [markdown]
# ## Steps done via code in the below cell
# - open anaconda prompt
# - Enter the following commands:
#     - For video concatenation:
#         - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\video_e3v83b3.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\e3v83b3_ffmpeg.mp4```
#     - For NIDAQ concatenation:
#         - - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0_ffmpeg.wav```

# %%
no_audio_files = int(len(glob.glob(path_concat + "*channel_*.txt"))/no_channels)
no_video_files = int(len(glob.glob(path_concat + "*video_*.txt"))/len(camera_names))

# %%
timestamp_record_data = cam_clk_data.iloc[timestamp_idx]
time_starts = []
time_ends = []
column_names = [i for i in timestamp_record_data.columns if i.endswith("file_name") and not(i.startswith('clk'))]

starting_timestamp = datetime.strptime(timestamp_record_data[column_names[0]][0].split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S')

# for camera_file in column_names:
#     for file_name in timestamp_record_data[camera_file]:
#         time_starts.append(datetime.strptime(file_name.split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S'))
#         time_ends.append(time_starts[-1] + timedelta(minutes=file_length/60))

# %%
# if no_audio_files != no_video_files:
#     raise Exception("Number of audio and video files don't match")
# else:
matched_csv = []
timestamp_write = starting_timestamp
f = open(path_final+"README.txt", 'w')
f.write("The files that are synced are as follows:\n")
f.write("Video file names - corresponding audio file names - timestamp range of file \n")
for i in range(no_audio_files):
    temp_0 = []
    temp_1 = []
    temp_2 = [timestamp_write.strftime("%Y-%m-%d %H:%M:%S"),(timestamp_write + timedelta(minutes=file_length/60)).strftime("%Y-%m-%d %H:%M:%S")]
    timestamp_write += timedelta(minutes=file_length/60)
    for j in range(no_channels):
        var_1 = "%03d"%(i)
        var_2 = "%02d"%(j)
        temp_0.append(f"channel_{var_2}_file_{var_1}")
    for j in camera_names:
        var_1 = "%03d"%(i)
        temp_1.append(f"video_{j}_{var_1}")
    f.write(f"[{', '.join(temp_1)}] - [{', '.join(temp_0)}] - [{', '.join(temp_2)}]\n")
    matched_csv.append([temp_1,temp_0,temp_2])
pd.DataFrame(matched_csv,columns=["video","audio","timestamp"]).to_csv(path_final+"sync.csv", index = False)
f.close()

# %%
filename_txt = path_concat + "*.txt"
txt_files = glob.glob(filename_txt)
video_files = []
audio_files = []

for file in txt_files:
    name = file.split('\\')[-1].split(".")[0]
    full_path_txt = path_concat+name+".txt"
    full_path_txt = full_path_txt.replace("/","\\")
    if name[0] == "c":
        continue
        full_path_wav = path_final+name+".wav"
        full_path_wav = full_path_wav.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
        # -rf64 auto
    else:
        full_path_mp4 = path_final+name+".mp4"
        full_path_mp4 = full_path_mp4.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy {full_path_mp4}
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000022957923240] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 25572 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 25572 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_000.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 25572 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000022957908E80] video:374592KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005452%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  374613KiB time=00:01:59.99 bitrate=25573.8kbits/s speed= 287x elapsed=0:00:00.41
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000247F71818C0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 24053 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 24053 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_001.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 24053 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 00000247F7166000] video:352350KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005780%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  352371KiB time=00:01:59.99 bitrate=24055.4kbits/s speed= 360x elapsed=0:00:00.33
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000010F934599C0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_002.txt':
#   Duration: N/A, start: 0.000000, bitrate: 24699 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 24699 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_002.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 24699 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000010F934599C0] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 0000010F93433880] video:359861KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005657%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  359881KiB time=00:01:59.99 bitrate=24568.1kbits/s speed= 260x elapsed=0:00:00.46
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000020EEA545740] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_003.txt':
#   Duration: N/A, start: 0.000000, bitrate: 23370 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 23370 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_003.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 23370 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000020EEE57B540] video:342332KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005944%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  342352KiB time=00:01:59.99 bitrate=23371.5kbits/s speed= 256x elapsed=0:00:00.46
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000268044C5580] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 22926 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 22926 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_004.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 22926 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame= 3002 fps=0.0 q=-1.0 size=  280064KiB time=00:01:40.33 bitrate=22866.9kbits/s speed= 196x elapsed=0:00:00.51
# [out#0/mp4 @ 00000268044AA240] video:335832KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.006063%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  335853KiB time=00:01:59.99 bitrate=22927.8kbits/s speed= 167x elapsed=0:00:00.72
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000252ABEF6280] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_005.txt':
#   Duration: N/A, start: 0.000000, bitrate: 22873 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 22873 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_005.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 22873 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000252ABEFE280] Auto-inserting h264_mp4toannexb bitstream filter
# frame= 1626 fps=0.0 q=-1.0 size=  151040KiB time=00:00:54.46 bitrate=22717.2kbits/s speed= 109x elapsed=0:00:00.50
# frame= 1626 fps=1602 q=-1.0 size=  151040KiB time=00:00:54.46 bitrate=22717.2kbits/s speed=53.6x elapsed=0:00:01.01
# frame= 1626 fps=1064 q=-1.0 size=  151040KiB time=00:00:54.46 bitrate=22717.2kbits/s speed=35.6x elapsed=0:00:01.52
# frame= 1649 fps=807 q=-1.0 size=  152832KiB time=00:00:55.23 bitrate=22667.7kbits/s speed=  27x elapsed=0:00:02.04
# frame= 1649 fps=645 q=-1.0 size=  152832KiB time=00:00:55.23 bitrate=22667.7kbits/s speed=21.6x elapsed=0:00:02.55
# frame= 1649 fps=537 q=-1.0 size=  152832KiB time=00:00:55.23 bitrate=22667.7kbits/s speed=  18x elapsed=0:00:03.07
# frame= 1660 fps=463 q=-1.0 size=  154112KiB time=00:00:55.59 bitrate=22706.8kbits/s speed=15.5x elapsed=0:00:03.58
# frame= 1660 fps=405 q=-1.0 size=  154112KiB time=00:00:55.59 bitrate=22706.8kbits/s speed=13.6x elapsed=0:00:04.10
# frame= 2011 fps=436 q=-1.0 size=  186624KiB time=00:01:07.29 bitrate=22716.8kbits/s speed=14.6x elapsed=0:00:04.61
# frame= 2054 fps=401 q=-1.0 size=  190720KiB time=00:01:08.73 bitrate=22731.2kbits/s speed=13.4x elapsed=0:00:05.12
# frame= 2084 fps=369 q=-1.0 size=  193792KiB time=00:01:09.73 bitrate=22766.2kbits/s speed=12.4x elapsed=0:00:05.64
# frame= 2406 fps=391 q=-1.0 size=  223488KiB time=00:01:20.46 bitrate=22752.7kbits/s speed=13.1x elapsed=0:00:06.15
# frame= 3062 fps=459 q=-1.0 size=  284416KiB time=00:01:42.33 bitrate=22768.3kbits/s speed=15.3x elapsed=0:00:06.66
# [out#0/mp4 @ 00000252ABED42C0] video:335130KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.006103%
# frame= 3600 fps=432 q=-1.0 Lsize=  335151KiB time=00:01:59.99 bitrate=22879.9kbits/s speed=14.4x elapsed=0:00:08.33
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000002C3D1FD0F40] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_006.txt':
#   Duration: N/A, start: 0.000000, bitrate: 23976 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 23976 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_006.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 23976 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame= 1563 fps=0.0 q=-1.0 size=  148224KiB time=00:00:52.36 bitrate=23187.7kbits/s speed= 103x elapsed=0:00:00.50
# [out#0/mp4 @ 000002C3D1FB5C40] video:351216KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005805%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  351237KiB time=00:01:59.99 bitrate=23978.0kbits/s speed= 150x elapsed=0:00:00.79
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000294EFCF0040] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_007.txt':
#   Duration: N/A, start: 0.000000, bitrate: 24620 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 24620 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_007.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 24620 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame=    1 fps=0.0 q=-1.0 size=       0KiB time=00:00:00.29 bitrate=   1.3kbits/s speed=0.587x elapsed=0:00:00.51
# frame= 1077 fps=1054 q=-1.0 size=  106752KiB time=00:00:36.16 bitrate=24180.3kbits/s speed=35.4x elapsed=0:00:01.02
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000294EFCF0040] Auto-inserting h264_mp4toannexb bitstream filter
# frame= 3289 fps=2140 q=-1.0 size=  330496KiB time=00:01:49.89 bitrate=24635.6kbits/s speed=71.5x elapsed=0:00:01.53
# [out#0/mp4 @ 00000294EFCD1380] video:361921KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005597%
# frame= 3600 fps=1974 q=-1.0 Lsize=  361942KiB time=00:01:59.99 bitrate=24708.8kbits/s speed=65.8x elapsed=0:00:01.82
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000028FA3DB8700] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_008.txt':
#   Duration: N/A, start: 0.000000, bitrate: 23524 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 23524 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_008.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 23524 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame= 3516 fps=0.0 q=-1.0 size=  336896KiB time=00:01:57.19 bitrate=23548.5kbits/s speed= 234x elapsed=0:00:00.50
# [out#0/mp4 @ 0000028FA3D90740] video:344591KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.005896%
# frame= 3600 fps=0.0 q=-1.0 Lsize=  344611KiB time=00:01:59.99 bitrate=23525.7kbits/s speed= 236x elapsed=0:00:00.50
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001D97B44CB40] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\temp\video_gily_center_009.txt':
#   Duration: N/A, start: 0.000000, bitrate: 22892 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 22892 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_311\concatenated_data_cam_mic_sync\video_gily_center_009.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 22892 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame=    1 fps=0.0 q=-1.0 size=       0KiB time=00:00:00.29 bitrate=   1.3kbits/s speed=0.592x elapsed=0:00:00.50
# frame= 1158 fps=1149 q=-1.0 size=  108032KiB time=00:00:38.86 bitrate=22770.3kbits/s speed=38.6x elapsed=0:00:01.00
# [out#0/mp4 @ 000001D97B4258C0] video:231945KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.006188%
# frame= 2490 fps=1778 q=-1.0 Lsize=  231960KiB time=00:01:22.99 bitrate=22894.4kbits/s speed=59.3x elapsed=0:00:01.40

# %% [markdown]
# old camera frame rate - 1/0.03338542
#
# new camera frame rate -
