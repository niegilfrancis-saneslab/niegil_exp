# %% [markdown]
# ### Note: Please ensure that this notebook is run in the daq environment

# %%
import glob
import os
import tqdm
from collections import defaultdict
import re
import numpy as np
import pandas as pd
from scipy.io import wavfile
# from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.video.io.VideoFileClip import VideoFileClip
from datetime import datetime, timedelta
import copy

# %%
# def seconds_to_hms(seconds):
#     # Calculate hours, minutes, and seconds
#     hours, remainder = divmod(seconds, 3600)
#     minutes, seconds = divmod(remainder, 60)
#     # Format the time in HH:MM:SS
#     return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}.{int(remainder%1*1000):03}"

# %%
from moviepy.tools import subprocess_call
from moviepy.config import get_setting

# def ffmpeg_extract_subclip(filename, t1, t2, targetname=None):
def ffmpeg_extract_subclip(filename, start_frame, end_frame, targetname=None):
    """ Makes a new video file playing video file ``filename`` between
    the times ``t1`` and ``t2``. """
    # !ffmpeg -i {filename} -ss {seconds_to_hms(t1)} -to {seconds_to_hms(t2)} -c copy {targetname}
    tmp_str = f"between(n\,{start_frame}\,{end_frame}),setpts=PTS-STARTPTS"
    # !ffmpeg -i {filename} -vf select={tmp_str} -c:v libx264 -crf 0 {targetname}

# %%
experiment_no = 439
no_channels = 13
camera_fps = 30
# camera_corrected_sample_time = 0.03338542
file_length = 120 # in seconds (120 sec - 2 mins)
sampling_rate = 125000
# nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
video_folder = "D:/big_setup/experiment_{}/videos/".format(experiment_no)

# %%
# Deleting the trunc files if it is already present
trunc_files = glob.glob(nidaq_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i) 

trunc_files = glob.glob(video_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i)

# %%
nidaq_files = glob.glob(nidaq_folder+"*")
video_files = glob.glob(video_folder+"*")

# %%
# Creating separate folders for the concatenated data
path_concat = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/temp/".format(experiment_no)

try:
    os.makedirs(path_concat)
except:
    pass

# %%
path_final = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/".format(experiment_no)

# %%
# deleting the vid files and the temp files
concat_vid_files = glob.glob(path_final+"video*.mp4")
for i in concat_vid_files:
    os.remove(i) 

concat_vid_txt_files = glob.glob(path_concat+"video*.txt")
for i in concat_vid_txt_files:
    os.remove(i)

# %%
# Functions to sort file names correctly
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
nidaq_files.sort(key=natural_keys)
video_files.sort(key=natural_keys)

# %%
nidaq_files = [i.replace("\\",'/') for i in nidaq_files]
video_files = [i.replace("\\",'/') for i in video_files]

# %% [markdown]
# ### For Videos

# %%
# Getting the camera names
temp_cam_name = []
for i in video_files:
    temp_cam_name.append(i.split("/")[-1].split("-")[0])
camera_names = list(set(temp_cam_name))
print(camera_names)
# Out:
# ['gily_center']

# %%
# Creating a dictionary of all videos of a single camera
video_by_camera = defaultdict(lambda:[])
for idx,name in enumerate(temp_cam_name):
    video_by_camera[name].append(video_files[idx])

# %%
cam_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")

# %%
file_breaks  = np.arange(0,cam_clk_data.tail(1).index[0]/camera_fps,file_length)
last_break = cam_clk_data.tail(1).index[0]
timestamp_idx = []
for val in file_breaks:
    timestamp_idx.append((np.abs(cam_clk_data[f'concat_{camera_names[0]}_time_from_vid_start'] - val)).argmin())

# %%
if timestamp_idx[-1] != last_break:
    timestamp_idx.append(last_break)

# %% [markdown]
# ### Assumes
# - 5 min original videos and shorter concatenated videos
# - concatenation starts from 0.0 of first video for each camera
# - all videos are recorded properly

# %%
vals = []
for cam in camera_names:
    file_concat_index = 0 
    no_videos = len(video_by_camera[cam])
    id = 0
    
    temp = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_file_name'].split('\\')
    prev_vid_name = temp[0]+'/'+temp[1]
    # prev_break_time = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_time_from_vid_start']
    prev_break_frame = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_frame_idx']
    prev_file_break = timestamp_idx[0]

    for file_break in tqdm.tqdm(timestamp_idx[1:]):

            #--------------------------------------- edited -----------------------------------------------

            temp = cam_clk_data.iloc[file_break][f'{cam}_file_name'].split('\\')
            vid_name = temp[0]+'/'+temp[1]
            # break_time = cam_clk_data.iloc[file_break][f'{cam}_time_from_vid_start']
            break_frame = cam_clk_data.iloc[file_break][f'{cam}_frame_idx']
            str_1 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"video_{cam}_{str_1}.txt"

            if prev_vid_name != vid_name: # when we reach the end of a saved file and start a new one

                with VideoFileClip(prev_vid_name) as video:
                    # end_time = video.duration
                    end_frame = video.reader.nframes
                    
                    # vals.append([end_time,prev_break_time])
                    # if end_time-prev_break_time > 1:
                    if end_frame-prev_break_frame > 1:
                        tmp = cam_clk_data.iloc[prev_file_break][f'{cam}_file_name'].split('\\')
                        target_file = tmp[0]+"/"+tmp[1].split(".")[0]+f"_trunc_{id}.mp4"      
                        # ffmpeg_extract_subclip(prev_vid_name, prev_break_time, end_time, targetname=target_file)
                        ffmpeg_extract_subclip(prev_vid_name, prev_break_frame, end_frame-1, targetname=target_file)
                
                        f = open(filename_txt, 'a')
                        f.write("file \'{}\'\n".format(target_file))
                        f.close()
                    
                    # prev_break_time = 0.0
                    prev_break_frame = 0
                    id = 0
                    
            target_file = temp[0]+"/"+temp[1].split(".")[0]+f"_trunc_{id}.mp4"
            # ffmpeg_extract_subclip(vid_name, prev_break_time, break_time, targetname=target_file)
            ffmpeg_extract_subclip(vid_name, prev_break_frame, break_frame-1, targetname=target_file)

            f = open(filename_txt, 'a')
            f.write("file \'{}\'\n".format(target_file))
            f.close()
            
            # prev_break_time = copy.deepcopy(break_time)
            prev_break_frame =  copy.deepcopy(break_frame)
            id+=1
            file_concat_index+=1
            prev_vid_name = copy.deepcopy(vid_name)
            prev_file_break = copy.deepcopy(file_break)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_439/videos/gily_center-20251217T141305-141805.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:04:59.96, start: 0.000000, bitrate: 4449 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4446 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0000015326AF30C0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 
iB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003701%
# frame= 3600 fps=136 q=-1.0 Lsize=  602118KiB time=00:01:59.99 bitrate=41105.0kbits/s speed=4.55x elapsed=0:00:26.39
# [libx264 @ 0000015326AF30C0] frame I:15    Avg QP: 0.00  size:467517
# [libx264 @ 0000015326AF30C0] frame P:3585  Avg QP: 0.00  size:170023
# [libx264 @ 0000015326AF30C0] mb I  I16..4: 27.0% 14.0% 59.0%
# [libx264 @ 0000015326AF30C0] mb P  I16..4:  5.0%  4.4%  2.1%  P16..4: 51.0%  9.0% 21.8%  0.0%  0.0%    skip: 6.7%
# [libx264 @ 0000015326AF30C0] 8x8 transform intra:37.0% inter:52.0%
# [libx264 @ 0000015326AF30C0] coded y,uvDC,uvAC intra: 85.4% 0.0% 0.0% inter: 66.9% 0.0% 0.0%
# [libx264 @ 0000015326AF30C0] i16 v,h,dc,p: 60% 39%  1%  0%
# [libx264 @ 0000015326AF30C0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 32% 31%  3%  2%  1%  1%  1%  1%
# [libx264 @ 0000015326AF30C0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 39%  2%  2%  3%  2%  2%  1%  2%
# [libx264 @ 0000015326AF30C0] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0000015326AF30C0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0000015326AF30C0] ref P L0: 87.8%  9.7%  1.9%  0.5%
# [libx264 @ 0000015326AF30C0] kb/s:41103.43
#   3%|▎         | 1/30 [00:27<13:15, 27.43s/it]ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_439/videos/gily_center-20251217T141305-141805.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:04:59.96, start: 0.000000, bitrate: 4449 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4446 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 00000278AB28E040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 00000278AB28E040] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 00000278AB28E040] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_439/videos/gily_center-20251217T141305-141805_trunc_1.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A elapsed=0:00:01.53
# frame=   79 fps= 39 q=0.0 size=   13056KiB time=00:00:02.63 bitrate=40616.3kbits/s speed=1.28x elapsed=0:00:02.04
# frame=  177 fps= 69 q=0.0 size=   28672KiB time=00:00:05.89 bitrate=39810.8kbits/s speed= 2.3x elapsed=0:00:02.56
# frame=  281 fps= 91 q=0.0 size=   46336KiB time=00:00:09.36 bitrate=40525.5kbits/s speed=3.04x elapsed=0:00:03.07
# frame=  388 fps=108 q=0.0 size=   63488KiB time=00:00:12.93 bitrate=40213.9kbits/s speed= 3.6x elapsed=0:00:03.59
# frame=  479 fps=117 q=0.0 size=   78080KiB time=00:00:15.96 bitrate=40060.8kbits/s speed=3.89x elapsed=0:00:04.10
# frame=  594 fps=129 q=0.0 size=   97280KiB time=00:00:19.79 bitrate=40248.8kbits/s speed= 4.3x elapsed=0:00:04.60
# frame=  694 fps=136 q=0.0 size=  113664KiB time=00:00:23.13 bitrate=40251.2kbits/s speed=4.52x elapsed=0:00:05.12
# frame=  809 fps=144 q=0.0 size=  132608KiB time=00:00:26.96 bitrate=40284.4kbits/s speed= 4.8x elapsed=0:00:05.62
# frame=  913 fps=149 q=0.0 size=  150272KiB time=00:00:30.43 bitrate=40450.4kbits/s speed=4.96x elapsed=0:00:06.13
# frame= 1035 fps=156 q=0.0 size=  170752KiB time=00:00:34.49 bitrate=40545.4kbits/s speed=5.19x elapsed=0:00:06.65
iB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003877%
# frame= 1801 fps=117 q=-1.0 Lsize=  300829KiB time=00:01:00.03 bitrate=41050.8kbits/s speed=3.89x elapsed=0:00:15.42
# [libx264 @ 00000180BDED1100] frame I:8     Avg QP: 0.00  size:466630
# [libx264 @ 00000180BDED1100] frame P:1793  Avg QP: 0.00  size:169717
# [libx264 @ 00000180BDED1100] mb I  I16..4: 24.7% 12.8% 62.5%
# [libx264 @ 00000180BDED1100] mb P  I16..4:  5.0%  4.2%  2.0%  P16..4: 51.3%  9.0% 21.8%  0.0%  0.0%    skip: 6.6%
# [libx264 @ 00000180BDED1100] 8x8 transform intra:36.4% inter:52.1%
# [libx264 @ 00000180BDED1100] coded y,uvDC,uvAC intra: 85.9% 0.0% 0.0% inter: 67.0% 0.0% 0.0%
# [libx264 @ 00000180BDED1100] i16 v,h,dc,p: 60% 39%  1%  0%
# [libx264 @ 00000180BDED1100] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 32% 31%  3%  2%  1%  1%  1%  1%
# [libx264 @ 00000180BDED1100] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 40%  2%  2%  3%  2%  2%  2%  2%
# [libx264 @ 00000180BDED1100] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 00000180BDED1100] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 00000180BDED1100] ref P L0: 87.9%  9.7%  1.9%  0.5%
# [libx264 @ 00000180BDED1100] kb/s:41049.12
#  10%|█         | 3/30 [01:17<11:49, 26.29s/it]ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_439/videos/gily_center-20251217T141805-142306.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.03, start: 0.000000, bitrate: 4380 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4377 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 000001A8A091E540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000001A8A091E540] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 000001A8A091E540] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_439/videos/gily_center-20251217T141805-142306_trunc_1.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=1.0 q=0.0 size=       0KiB time=00:00:00.29 bitrate=   1.3kbits/s speed=0.292x elapsed=0:00:01.02
# frame=  118 fps= 77 q=0.0 size=   19200KiB time=00:00:03.93 bitrate=39988.6kbits/s speed=2.55x elapsed=0:00:01.54
# frame=  210 fps=102 q=0.0 size=   34048KiB time=00:00:06.99 bitrate=39846.3kbits/s speed=3.41x elapsed=0:00:02.05
# frame=  329 fps=128 q=0.0 size=   54016KiB time=00:00:10.96 bitrate=40349.9kbits/s speed=4.27x elapsed=0:00:02.56
# frame=  421 fps=137 q=0.0 size=   69120KiB time=00:00:14.03 bitrate=40349.4kbits/s speed=4.57x elapsed=0:00:03.06
# frame=  540 fps=151 q=0.0 size=   88320KiB time=00:00:17.99 bitrate=40195.8kbits/s speed=5.02x elapsed=0:00:03.58
# frame=  638 fps=156 q=0.0 size=  105216KiB time=00:00:21.26 bitrate=40530.0kbits/s speed=5.19x elapsed=0:00:04.09
# frame=  745 fps=162 q=0.0 size=  122880KiB time=00:00:24.83 bitrate=40536.0kbits/s speed=5.38x elapsed=0:00:04.61
# frame=  858 fps=167 q=0.0 size=  141824KiB time=00:00:28.59 bitrate=40623.6kbits/s speed=5.58x elapsed=0:00:05.12
# frame=  959 fps=170 q=0.0 size=  158208KiB time=00:00:31.96 bitrate=40543.9kbits/s speed=5.67x elapsed=0:00:05.63
# frame= 1068 fps=174 q=0.0 size=  177152KiB time=00:00:35.59 bitrate=40765.3kbits/s speed=5.79x elapsed=0:00:06.15
iB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003760%
# frame= 3600 fps=197 q=-1.0 Lsize=  595159KiB time=00:01:59.99 bitrate=40630.0kbits/s speed=6.56x elapsed=0:00:18.30
# [libx264 @ 000001A8A091E540] frame I:15    Avg QP: 0.00  size:457787
# [libx264 @ 000001A8A091E540] frame P:3585  Avg QP: 0.00  size:168076
# [libx264 @ 000001A8A091E540] mb I  I16..4: 24.9% 13.8% 61.3%
# [libx264 @ 000001A8A091E540] mb P  I16..4:  5.0%  4.3%  2.0%  P16..4: 51.3%  8.9% 21.7%  0.0%  0.0%    skip: 6.9%
# [libx264 @ 000001A8A091E540] 8x8 transform intra:37.0% inter:52.2%
# [libx264 @ 000001A8A091E540] coded y,uvDC,uvAC intra: 85.4% 0.0% 0.0% inter: 66.6% 0.0% 0.0%
# [libx264 @ 000001A8A091E540] i16 v,h,dc,p: 62% 38%  1%  0%
# [libx264 @ 000001A8A091E540] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 31% 31%  2%  3%  1%  2%  1%  1%
# [libx264 @ 000001A8A091E540] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 39%  2%  2%  4%  2%  3%  1%  2%
# [libx264 @ 000001A8A091E540] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 000001A8A091E540] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000001A8A091E540] ref P L0: 87.9%  9.6%  2.0%  0.5%  0.0%
# [libx264 @ 000001A8A091E540] kb/s:40628.40
#  13%|█▎        | 4/30 [01:36<10:05, 23.29s/it]ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_439/videos/gily_center-20251217T141805-142306.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.03, start: 0.000000, bitrate: 4380 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4377 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 000001DFBE1F6040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000001DFBE1F6040] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 000001DFBE1F6040] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_439/videos/gily_center-20251217T141805-142306_trunc_2.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   22 fps= 11 q=0.0 size=    3584KiB time=00:00:00.73 bitrate=40037.5kbits/s speed=0.362x elapsed=0:00:02.02
# frame=  132 fps= 52 q=0.0 size=   21760KiB time=00:00:04.39 bitrate=40513.7kbits/s speed=1.73x elapsed=0:00:02.53
# frame=  239 fps= 78 q=0.0 size=   39168KiB time=00:00:07.96 bitrate=40276.3kbits/s speed=2.61x elapsed=0:00:03.05
# frame=  300 fps= 84 q=0.0 size=   49408KiB time=00:00:09.99 bitrate=40475.5kbits/s speed=2.82x elapsed=0:00:03.55
# frame=  415 fps=102 q=0.0 size=   68864KiB time=00:00:13.83 bitrate=40781.2kbits/s speed= 3.4x elapsed=0:00:04.06
# frame=  540 fps=118 q=0.0 size=   89600KiB time=00:00:17.99 bitrate=40778.4kbits/s speed=3.94x elapsed=0:00:04.56
# frame=  658 fps=129 q=0.0 size=  109056KiB time=00:00:21.93 bitrate=40732.3kbits/s speed=4.32x elapsed=0:00:05.08
# frame=  779 fps=139 q=0.0 size=  129280KiB time=00:00:25.96 bitrate=40785.9kbits/s speed=4.64x elapsed=0:00:05.59
# frame=  885 fps=145 q=0.0 size=  146944KiB time=00:00:29.49 bitrate=40806.0kbits/s speed=4.83x elapsed=0:00:06.11
# frame=  990 fps=149 q=0.0 size=  163840KiB time=00:00:32.99 bitrate=40672.5kbits/s speed=4.98x elapsed=0:00:06.62
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001DCE3D25900] Packet corrupt (stream = 0, dts = 2800305330).
# [h264 @ 000001DCE3D5AC00] Invalid NAL unit size (22775 > 4422).
# [h264 @ 000001DCE3D5AC00] missing picture in access unit with size 4426
# [in#0/mov,mp4,m4a,3gp,3g2,mj2 @ 000001DCE3D25780] corrupt input packet in stream 0
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001DCE3D25900] stream 0, offset 0x8bda4eb: partial file
# [h264 @ 000001DCE864E640] Invalid NAL unit size (22775 > 4422).
# [h264 @ 000001DCE864E640] Error splitting the input into NAL units.
# [vist#0:0/h264 @ 000001DCE3CC5240] [dec:h264 @ 000001DCE3D86500] Decoding error: Invalid data found when processing input
# [out#0/mp4 @ 000001DCE3D19C40] video:580604KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003804%
# frame= 3600 fps=198 q=-1.0 Lsize=  580626KiB time=00:01:59.99 bitrate=39637.8kbits/s speed=6.61x elapsed=0:00:18.16
# [libx264 @ 000001DCE3D609C0] frame I:15    Avg QP: 0.00  size:459502
# [libx264 @ 000001DCE3D609C0] frame P:3585  Avg QP: 0.00  size:163918
# [libx264 @ 000001DCE3D609C0] mb I  I16..4: 25.6% 14.8% 59.6%
# [libx264 @ 000001DCE3D609C0] mb P  I16..4:  4.8%  4.0%  1.6%  P16..4: 52.0%  8.8% 21.7%  0.0%  0.0%    skip: 7.1%
# [libx264 @ 000001DCE3D609C0] 8x8 transform intra:37.8% inter:52.0%
# [libx264 @ 000001DCE3D609C0] coded y,uvDC,uvAC intra: 84.8% 0.0% 0.0% inter: 66.2% 0.0% 0.0%
# [libx264 @ 000001DCE3D609C0] i16 v,h,dc,p: 60% 39%  1%  0%
# [libx264 @ 000001DCE3D609C0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 31% 32%  3%  2%  1%  1%  1%  1%
# [libx264 @ 000001DCE3D609C0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 39%  2%  2%  3%  1%  2%  1%  2%
# [libx264 @ 000001DCE3D609C0] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 000001DCE3D609C0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000001DCE3D609C0] ref P L0: 88.1%  9.3%  2.0%  0.5%  0.0%
# [libx264 @ 000001DCE3D609C0] kb/s:39636.23
#  97%|█████████▋| 29/30 [13:13<00:23, 23.38s/it]ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_439/videos/gily_center-20251217T150811-151251.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:04:41.00, start: 0.000000, bitrate: 4174 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4183 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 00000137A05CEA40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 00000137A05CEA40] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 00000137A05CEA40] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_439/videos/gily_center-20251217T150811-151251_trunc_2.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x1200, q=2-31, 30 fps, 1000k tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=
# frame= 2607 fps=189 q=0.0 size=  413184KiB time=00:01:26.89 bitrate=38951.0kbits/s speed= 6.3x elapsed=0:00:13.79
# frame= 2730 fps=191 q=0.0 size=  432384KiB time=00:01:30.99 bitrate=38924.5kbits/s speed=6.36x elapsed=0:00:14.30
# frame= 2856 fps=193 q=0.0 size=  452864KiB time=00:01:35.19 bitrate=38969.5kbits/s speed=6.42x elapsed=0:00:14.82
# frame= 2970 fps=194 q=0.0 size=  470272KiB time=00:01:38.99 bitrate=38914.2kbits/s speed=6.46x elapsed=0:00:15.33
# frame= 3079 fps=194 q=0.0 size=  487680KiB time=00:01:42.63 bitrate=38926.1kbits/s speed=6.48x elapsed=0:00:15.84
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001379C5F6680] Packet corrupt (stream = 0, dts = 2800305330).
# [h264 @ 00000137A05CE6C0] Invalid NAL unit size (22775 > 4422).
# [h264 @ 00000137A05CE6C0] missing picture in access unit with size 4426
# [in#0/mov,mp4,m4a,3gp,3g2,mj2 @ 000001379C5F5580] corrupt input packet in stream 0
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001379C5F6680] stream 0, offset 0x8bda4eb: partial file
# [h264 @ 00000137A06882C0] Invalid NAL unit size (22775 > 4422).
# [h264 @ 00000137A06882C0] Error splitting the input into NAL units.
# [vist#0:0/h264 @ 000001379C639D40] [dec:h264 @ 000001379C65BD00] Decoding error: Invalid data found when processing input
# [out#0/mp4 @ 000001379C5ED4C0] video:498827KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003933%
# frame= 3150 fps=192 q=-1.0 Lsize=  498847KiB time=00:01:44.99 bitrate=38920.0kbits/s speed=6.41x elapsed=0:00:16.37
# [libx264 @ 00000137A05CEA40] frame I:13    Avg QP: 0.00  size:454142
# [libx264 @ 00000137A05CEA40] frame P:3137  Avg QP: 0.00  size:160948
# [libx264 @ 00000137A05CEA40] mb I  I16..4: 26.4% 13.8% 59.8%
# [libx264 @ 00000137A05CEA40] mb P  I16..4:  4.7%  3.9%  1.4%  P16..4: 52.3%  8.7% 21.7%  0.0%  0.0%    skip: 7.2%
# [libx264 @ 00000137A05CEA40] 8x8 transform intra:37.8% inter:52.2%
# [libx264 @ 00000137A05CEA40] coded y,uvDC,uvAC intra: 84.9% 0.0% 0.0% inter: 65.8% 0.0% 0.0%
# [libx264 @ 00000137A05CEA40] i16 v,h,dc,p: 60% 39%  1%  0%
# [libx264 @ 00000137A05CEA40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 31% 32%  3%  2%  1%  1%  1%  1%
# [libx264 @ 00000137A05CEA40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 49% 39%  2%  2%  3%  1%  2%  1%  2%
# [libx264 @ 00000137A05CEA40] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 00000137A05CEA40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 00000137A05CEA40] ref P L0: 88.2%  9.2%  2.0%  0.5%
# [libx264 @ 00000137A05CEA40] kb/s:38918.38
# 100%|██████████| 30/30 [13:30<00:00, 27.02s/it]

# %% [markdown]
# ### For NIDAQ

# %%
# Reading the timestamps data for the camera clock channel 
audio_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")
audio_start_rec_idx = int(cam_clk_data["clk_ch_file_name"][0].split("\\")[1].split("_")[2])
audio_stop_rec_idx = int(cam_clk_data["clk_ch_file_name"].iloc[-1].split("\\")[1].split("_")[2])
start_sample_index =  int(cam_clk_data["clk_ch_sample_idx"][0])
end_sample_index =  int(cam_clk_data["clk_ch_sample_idx"].iloc[-1])

# %%
# Concatenating the microphone channels
for ch_no in range(no_channels):
    file_concat_index = 0 
    id = 0

    prev_ch_name = "_".join(audio_clk_data.iloc[timestamp_idx[0]][f'clk_ch_file_name'].split("_")[:-1])+f"_{ch_no}.wav"
    prev_break_idx = audio_clk_data.iloc[timestamp_idx[0]][f'clk_ch_sample_idx']


    for file_break in tqdm.tqdm(timestamp_idx[1:]):

            #--------------------------------------- edited -----------------------------------------------

            ch_name = "_".join(audio_clk_data.iloc[file_break][f'clk_ch_file_name'].split("_")[:-1])+f"_{ch_no}.wav"
            break_idx = audio_clk_data.iloc[file_break][f'clk_ch_sample_idx']
            str_1 = "%02d"%(ch_no)
            str_2 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"channel_{str_1}_file_{str_2}.txt"

            if prev_ch_name != ch_name: # when we reach the end of a saved file and start a new one
                    if prev_break_idx < (sampling_rate*300)-1000:
                        target_file = prev_ch_name.split(".")[0]+f"_trunc_{id}.wav"   

                        # Loading the file
                        sampling_rate,ch = wavfile.read(prev_ch_name)
                        ch = ch[prev_break_idx:]
                        
                        wavfile.write(target_file,sampling_rate,ch)
                
                        f = open(filename_txt, 'a')
                        f.write("file \'{}\'\n".format(target_file))
                        f.close()
                    
                    prev_break_idx = 0
                    id = 0
                    
            target_file = ch_name.split(".")[0]+f"_trunc_{id}.wav"

            # Loading the file
            sampling_rate,ch = wavfile.read(ch_name)
            ch = ch[prev_break_idx:break_idx]
                        
            wavfile.write(target_file,sampling_rate,ch)
                
            f = open(filename_txt, 'a')
            f.write("file \'{}\'\n".format(target_file))
            f.close()
                    

            
            prev_break_idx = copy.deepcopy(break_idx)
            id+=1
            file_concat_index+=1
            prev_ch_name = copy.deepcopy(ch_name)
# Out:
# 100%|██████████| 21/21 [00:10<00:00,  1.97it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.79it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.73it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.70it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.63it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.72it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.65it/s]
# 100%|██████████| 21/21 [00:13<00:00,  1.59it/s]
# 100%|██████████| 21/21 [00:13<00:00,  1.60it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.66it/s]
# 100%|██████████| 21/21 [00:13<00:00,  1.59it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.62it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.66it/s]

# %% [markdown]
# ## Steps done via code in the below cell
# - open anaconda prompt
# - Enter the following commands:
#     - For video concatenation:
#         - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\video_e3v83b3.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\e3v83b3_ffmpeg.mp4```
#     - For NIDAQ concatenation:
#         - - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0_ffmpeg.wav```

# %%
no_audio_files = int(len(glob.glob(path_concat + "*channel_*.txt"))/no_channels)
no_video_files = int(len(glob.glob(path_concat + "*video_*.txt"))/len(camera_names))

# %%
timestamp_record_data = cam_clk_data.iloc[timestamp_idx]
time_starts = []
time_ends = []
column_names = [i for i in timestamp_record_data.columns if i.endswith("file_name") and not(i.startswith('clk'))]

starting_timestamp = datetime.strptime(timestamp_record_data[column_names[0]][0].split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S')

# for camera_file in column_names:
#     for file_name in timestamp_record_data[camera_file]:
#         time_starts.append(datetime.strptime(file_name.split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S'))
#         time_ends.append(time_starts[-1] + timedelta(minutes=file_length/60))

# %%
# if no_audio_files != no_video_files:
#     raise Exception("Number of audio and video files don't match")
# else:
matched_csv = []
timestamp_write = starting_timestamp
f = open(path_final+"README.txt", 'w')
f.write("The files that are synced are as follows:\n")
f.write("Video file names - corresponding audio file names - timestamp range of file \n")
for i in range(no_audio_files):
    temp_0 = []
    temp_1 = []
    temp_2 = [timestamp_write.strftime("%Y-%m-%d %H:%M:%S"),(timestamp_write + timedelta(minutes=file_length/60)).strftime("%Y-%m-%d %H:%M:%S")]
    timestamp_write += timedelta(minutes=file_length/60)
    for j in range(no_channels):
        var_1 = "%03d"%(i)
        var_2 = "%02d"%(j)
        temp_0.append(f"channel_{var_2}_file_{var_1}")
    for j in camera_names:
        var_1 = "%03d"%(i)
        temp_1.append(f"video_{j}_{var_1}")
    f.write(f"[{', '.join(temp_1)}] - [{', '.join(temp_0)}] - [{', '.join(temp_2)}]\n")
    matched_csv.append([temp_1,temp_0,temp_2])
pd.DataFrame(matched_csv,columns=["video","audio","timestamp"]).to_csv(path_final+"sync.csv", index = False)
f.close()

# %%
filename_txt = path_concat + "*.txt"
txt_files = glob.glob(filename_txt)
video_files = []
audio_files = []

for file in txt_files:
    name = file.split('\\')[-1].split(".")[0]
    full_path_txt = path_concat+name+".txt"
    full_path_txt = full_path_txt.replace("/","\\")
    if name[0] == "c":
        continue
        full_path_wav = path_final+name+".wav"
        full_path_wav = full_path_wav.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
        # -rf64 auto
    else:
        full_path_mp4 = path_final+name+".mp4"
        full_path_mp4 = full_path_mp4.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy {full_path_mp4}
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001F2BF6C9D40] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\temp\video_gily_center_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 41103 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 41103 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\video_gily_center_000.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 41103 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# fr
iB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003703%
# frame= 3600 fps=107 q=-1.0 Lsize=  602118KiB time=00:01:59.99 bitrate=41105.0kbits/s speed=3.57x elapsed=0:00:33.61
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000022AD935B940] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\temp\video_gily_center_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 40941 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 40941 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\video_gily_center_001.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 40941 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame=   31 fps=0.0 q=-1.0 size=    4864KiB time=00:00:01.03 bitrate=38561.3kbits/s speed=2.03x elapsed=0:00:00.50
# frame=   90 fps= 89 q=-1.0 size=   14592KiB time=00:00:02.99 bitrate=39846.4kbits/s speed=2.97x elapsed=0:00:01.01
# frame=   98 fps= 64 q=-1.0 size=   16128KiB time=00:00:03.26 bitrate=40445.6kbits/s speed=2.14x elapsed=0:00:01.52
# frame=  128 fps= 63 q=-1.0 size=   20992KiB time=00:00:04.26 bitrate=40305.1kbits/s speed=2.09x elapsed=0:00:02.03
# frame=  131 fps= 51 q=-1.0 size=   21504KiB time=00:00:04.36 bitrate=40342.7kbits/s speed=1.71x elapsed=0:00:02.55
# frame=  240 fps= 78 q=-1.0 size=   38912KiB time=00:00:07.99 bitrate=39846.3kbits/s speed=2.61x elapsed=0:00:03.06
# frame=  241 fps= 67 q=-1.0 size=   38912KiB time=00:00:08.03 bitrate=39681.0kbits/s speed=2.25x elapsed=0:00:03.57
# frame=  305 fps= 75 q=-1.0 size=   50176KiB time=00:00:10.16 bitrate=40430.8kbits/s speed=2.49x elapsed=0:00:04.08
# frame=  394 fps= 86 q=-1.0 size=   64768KiB time=00:00:13.13 bitrate=40399.9kbits/s speed=2.85x elapsed=0:00:04.60
# frame=  432 fps= 84 q=-1.0 size=   70912KiB time=00:00:14.39 bitrate=40341.5kbits/s speed=2.81x elapsed=0:00:05.11
# frame=  499 fps= 89 q=-1.0 size=   81664KiB time=00:00:16.63 bitrate=40220.4kbits/s speed=2.95x elapsed=0:00:05.63
# frame=  636 fps=103 q=-1.0 size=  104192KiB time=00:00:21.19 bitrate=40261.8kbits/s speed=3.45x elapsed=0:00:06.14
# frame=  636 fps= 95 q=-1.0 size=  104192KiB time=00:00:21.19 bitrate=40261.8kbits/s speed=3.18x elapsed=0:00:06.66
# frame=  636 fps= 89 q=-1.0 size=  104192KiB time=00:00:21.19 bitrate=40261.8kbits/s speed=2.96x elapsed=0:00:07.17
# frame=  636 fps= 83 q=-1.0 size=  104192KiB time=00:00:21.19 bitrate=40261.8kbits/s speed=2.76x elapsed=0:00:07.67
# frame=  698 fps= 85 q=-1.0 size=  114176KiB time=00:00:23.26 bitrate=40200.8kbits/s speed=2.84x elapsed=0:00:08.18
# frame=  749 fps= 86 q=-1.0 size=  122368KiB time=00:00:24.96 bitrate=40151.5kbits/s speed=2.87x elapsed=0:00:08.70
# frame=  762 fps= 83 q=-1.0 size=  124928KiB time=00:00:25.39 bitrate=40292.2kbits/s speed=2.76x elapsed=0:00:09.21
# frame=  767 fps= 79 q=-1.0 size=  125696KiB time=00:00:25.56 bitrate=40275.6kbits/s speed=2.63x elapsed=0:00:09.73
# frame=  781 fps= 76 q=-1.0 size=  128000KiB time=00:00:26.03 bitrate=40278.6kbits/s speed=2.54x elapsed=0:00:10.24
# frame=  809 fps= 75 q=-1.0 size=  132608KiB time=00:00:26.96 bitrate=40284.4kbits/s speed=2.51x elapsed=0:00:10.74
# frame=  831 fps= 74 q=-1.0 size=  136448KiB time=00:00:27.69 bitrate=40353.6kbits/s speed=2.46x elapsed=0:00:11.24
# frame=  846 fps= 72 q=-1.0 size=  139008KiB time=00:00:28.19 bitrate=40381.7kbits/s speed= 2.4x elapsed=0:00:11.75
# frame=  846 fps= 69 q=-1.0 size=  139008KiB time=00:00:28.19 bitrate=40381.7kbits/s speed= 2.3x elapsed=0:00:12.25
# frame=  891 fps= 70 q=-1.0 size=  146176KiB time=00:00:29.69 bitrate=40319.4kbits/s speed=2.33x elapsed=0:00:12.76
# frame=  912 fps= 69 q=-1.0 size=  150016KiB time=00:00:30.39 bitrate=40425.8kbits/s speed=2.29x elapsed=0:00:13.27
# frame= 1060 fps= 77 q=-1.0 size=  175104KiB time=00:00:35.33 bitrate=40598.1kbits/s speed=2.56x elapsed=0:00:13.78
# frame= 1080 fps= 76 q=-1.0 size=  178176KiB time=00:00:35.99 bitrate=40545.4kbits/s speed=2.52x elapsed=0:00:14.28
# frame= 1119 fps= 76 q=-1.0 size=  185088KiB time=00:00:37.29 bitrate=40650.3kbits/s speed=2.52x elapsed=0:00:14.80
# frame= 1162 fps= 76 q=-1.0 size=  192000KiB time=00:00:38.73 bitrate=40607.9kbits/s speed=2.53x elapsed=0:00:15.31
# frame= 1403 fps= 89 q=-1.0 size=  232192KiB time=00:00:46.76 bitrate=40672.9kbits/s speed=2.95x elapsed=0:00:15.83
# frame= 1439 fps= 88 q=-1.0 size=  238080KiB time=00:00:47.96 bitrate=40661.0kbits/s speed=2.93x elapsed=0:00:16.34
# frame= 1444 fps= 86 q=-1.0 size=  239360KiB time=00:00:48.13 bitrate=40738.0kbits/s speed=2.86x elapsed=0:00:16.84
# frame= 1455 fps= 84 q=-1.0 size=  241152KiB time=00:00:48.49 bitrate=40732.7kbits/s speed=2.79x elapsed=0:00:17.35
# frame= 1468 fps= 82 q=-1.0 size=  242944KiB time=00:00:48.93 bitrate=40672.0kbits/s speed=2.74x elapsed=0:00:17.87
# frame= 1468 fps= 80 q=-1.0 size=  242944KiB time=00:00:48.93 bitrate=40672.0kbits/s speed=2.66x elapsed=0:00:18.38
# frame= 1515 fps= 80 q=-1.0 size=  251392KiB time=00:00:50.49 bitrate=40780.7kbits/s speed=2.67x elapsed=0:00:18.89
# frame= 1612 fps= 83 q=-1.0 size=  267264KiB time=00:00:53.73 bitrate=40746.6kbits/s speed=2.77x elapsed=0:00:19.41
# frame= 1655 fps= 83 q=-1.0 size=  274688KiB time=00:00:55.16 bitrate=40790.3kbits/s speed=2.77x elapsed=0:00:19.92
# frame= 1678 fps= 82 q=-1.0 size=  278272KiB time=00:00:55.93 bitrate=40756.2kbits/s speed=2.74x elapsed=0:00:20.43
# frame= 1688 fps= 81 q=-1.0 size=  280320KiB time=00:00:56.26 bitrate=40812.9kbits/s speed=2.69x elapsed=0:00:20.94
# frame= 1710 fps= 80 q=-1.0 size=  283392KiB time=00:00:56.99 bitrate=40729.3kbits/s speed=2.66x elapsed=0:00:21.46
# frame= 1895 fps= 86 q=-1.0 size=  314624KiB time=00:01:03.16 bitrate=40803.6kbits/s speed=2.87x elapsed=0:00:21.97
# frame= 1928 fps= 86 q=-1.0 size=  320000KiB time=00:01:04.26 bitrate=40790.5kbits/s speed=2.86x elapsed=0:00:22.47
# frame= 1953 fps= 85 q=-1.0 size=  324096KiB time=00:01:05.09 bitrate=40783.7kbits/s speed=2.83x elapsed=0:00:22.98
# frame= 2031 fps= 86 q=-1.0 size=  337408KiB time=00:01:07.69 bitrate=40828.3kbits/s speed=2.88x elapsed=0:00:23.49
# frame= 2154 fps= 90 q=-1.0 size=  358144KiB time=00:01:11.79 bitrate=40862.7kbits/s speed=2.99x elapsed=0:00:24.01
# frame= 2468 fps=101 q=-1.0 size=  410112KiB time=00:01:22.26 bitrate=40838.8kbits/s speed=3.35x elapsed=0:00:24.52
# frame= 2503 fps=100 q=-1.0 size=  416000KiB time=00:01:23.43 bitrate=40845.9kbits/s speed=3.33x elapsed=0:00:25.02
# frame= 2535 fps= 99 q=-1.0 size=  421376KiB time=00:01:24.49 bitrate=40851.4kbits/s speed=3.31x elapsed=0:00:25.53
# frame= 2565 fps= 98 q=-1.0 size=  425984KiB time=00:01:25.49 bitrate=40815.2kbits/s speed=3.28x elapsed=0:00:26.04
# frame= 2609 fps= 98 q=-1.0 size=  432896KiB time=00:01:26.96 bitrate=40777.9kbits/s speed=3.28x elapsed=0:00:26.54
# frame= 2616 fps= 97 q=-1.0 size=  434432KiB time=00:01:27.19 bitrate=40813.1kbits/s speed=3.22x elapsed=0:00:27.04
# frame= 2624 fps= 95 q=-1.0 size=  435712KiB time=00:01:27.46 bitrate=40808.6kbits/s speed=3.17x elapsed=0:00:27.55
# frame= 2634 fps= 94 q=-1.0 size=  437248KiB time=00:01:27.79 bitrate=40796.9kbits/s speed=3.13x elapsed=0:00:28.05
# frame= 2634 fps= 92 q=-1.0 size=  437248KiB time=00:01:27.79 bitrate=40796.9kbits/s speed=3.07x elapsed=0:00:28.57
# frame= 2634 fps= 91 q=-1.0 size=  437248KiB time=00:01:27.79 bitrate=40796.9kbits/s speed=3.02x elapsed=0:00:29.07
# frame= 2661 fps= 90 q=-1.0 size=  442112KiB time=00:01:28.69 bitrate=40832.2kbits/s speed=   3x elapsed=0:00:29.58
# frame= 2720 fps= 90 q=-1.0 size=  451840KiB time=00:01:30.66 bitrate=40825.5kbits/s speed=3.01x elapsed=0:00:30.09
# frame= 2777 fps= 91 q=-1.0 size=  461824KiB time=00:01:32.56 bitrate=40871.1kbits/s speed=3.02x elapsed=0:00:30.60
# frame= 2821 fps= 91 q=-1.0 size=  468992KiB time=00:01:34.03 bitrate=40858.1kbits/s speed=3.02x elapsed=0:00:31.11
# frame=  839 fps= 78 q=-1.0 size=  139776KiB time=00:00:27.96 bitrate=40943.6kbits/s speed=2.61x elapsed=0:00:10.73
# frame=  861 fps= 77 q=-1.0 size=  143360KiB time=00:00:28.69 bitrate=40920.5kbits/s speed=2.55x elapsed=0:00:11.24
# frame=  900 fps= 77 q=-1.0 size=  149504KiB time=00:00:29.99 bitrate=40825.0kbits/s speed=2.55x elapsed=0:00:11.76
# frame=  922 fps= 75 q=-1.0 size=  153344KiB time=00:00:30.73 bitrate=40874.4kbits/s speed= 2.5x elapsed=0:00:12.27
# frame=  947 fps= 74 q=-1.0 size=  157696KiB time=00:00:31.56 bitrate=40924.8kbits/s speed=2.47x elapsed=0:00:12.77
# frame=  990 fps= 74 q=-1.0 size=  164352KiB time=00:00:32.99 bitrate=40799.6kbits/s speed=2.48x elapsed=0:00:13.29
# frame= 1029 fps= 75 q=-1.0 size=  171264KiB time=00:00:34.29 bitrate=40904.1kbits/s speed=2.48x elapsed=0:00:13.80
# frame= 1065 fps= 74 q=-1.0 size=  177152KiB time=00:00:35.49 bitrate=40880.1kbits/s speed=2.48x elapsed=0:00:14.31
# frame= 1127 fps= 76 q=-1.0 size=  186880KiB time=00:00:37.56 bitrate=40752.5kbits/s speed=2.53x elapsed=0:00:14.83
# frame= 1172 fps= 76 q=-1.0 size=  193792KiB time=00:00:39.06 bitrate=40637.2kbits/s speed=2.55x elapsed=0:00:15.34
# frame= 1216 fps= 77 q=-1.0 size=  200960KiB time=00:00:40.53 bitrate=40615.5kbits/s speed=2.56x elapsed=0:00:15.85
# frame= 1241 fps= 76 q=-1.0 size=  205056KiB time=00:00:41.36 bitrate=40608.4kbits/s speed=2.53x elapsed=0:00:16.37
# frame= 1289 fps= 76 q=-1.0 size=  212992KiB time=00:00:42.96 bitrate=40609.3kbits/s speed=2.54x elapsed=0:00:16.88
# frame= 1320 fps= 76 q=-1.0 size=  218112KiB time=00:00:43.99 bitrate=40608.9kbits/s speed=2.53x elapsed=0:00:17.40
# frame= 1379 fps= 77 q=-1.0 size=  227840KiB time=00:00:45.96 bitrate=40605.2kbits/s speed=2.57x elapsed=0:00:17.91
# frame= 1436 fps= 78 q=-1.0 size=  236800KiB time=00:00:47.86 bitrate=40526.9kbits/s speed= 2.6x elapsed=0:00:18.41
# frame= 1478 fps= 78 q=-1.0 size=  243968KiB time=00:00:49.26 bitrate=40567.1kbits/s speed= 2.6x elapsed=0:00:18.92
# frame= 1481 fps= 76 q=-1.0 size=  244480KiB time=00:00:49.36 bitrate=40569.9kbits/s speed=2.54x elapsed=0:00:19.44
# frame= 1522 fps= 76 q=-1.0 size=  251136KiB time=00:00:50.73 bitrate=40551.8kbits/s speed=2.54x elapsed=0:00:19.95
# frame= 1552 fps= 76 q=-1.0 size=  256000KiB time=00:00:51.73 bitrate=40538.1kbits/s speed=2.53x elapsed=0:00:20.46
# frame= 1600 fps= 76 q=-1.0 size=  264448KiB time=00:00:53.33 bitrate=40619.6kbits/s speed=2.54x elapsed=0:00:20.97
# frame= 1651 fps= 77 q=-1.0 size=  272896KiB time=00:00:55.03 bitrate=40622.4kbits/s speed=2.56x elapsed=0:00:21.48
# frame= 1681 fps= 76 q=-1.0 size=  278016KiB time=00:00:56.03 bitrate=40646.0kbits/s speed=2.55x elapsed=0:00:21.99
# frame= 1728 fps= 77 q=-1.0 size=  286208KiB time=00:00:57.59 bitrate=40705.6kbits/s speed=2.56x elapsed=0:00:22.50
# frame= 1767 fps= 77 q=-1.0 size=  292864KiB time=00:00:58.89 bitrate=40732.9kbits/s speed=2.56x elapsed=0:00:23.02
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000026C58260500] Auto-inserting h264_mp4toannexb bitstream filter
# frame= 1801 fps= 77 q=-1.0 size=  298496KiB time=00:01:00.03 bitrate=40732.4kbits/s speed=2.55x elapsed=0:00:23.53
# frame= 1831 fps= 76 q=-1.0 size=  303360KiB time=00:01:01.03 bitrate=40717.9kbits/s speed=2.54x elapsed=0:00:24.05
# frame= 1889 fps= 77 q=-1.0 size=  313088KiB time=00:01:02.96 bitrate=40733.3kbits/s speed=2.56x elapsed=0:00:24.56
# frame= 1943 fps= 77 q=-1.0 size=  322048KiB time=00:01:04.76 bitrate=40734.6kbits/s speed=2.58x elapsed=0:00:25.08
# frame= 1991 fps= 78 q=-1.0 size=  330240KiB time=00:01:06.36 bitrate=40763.7kbits/s speed=2.59x elapsed=0:00:25.59
# frame= 2042 fps= 78 q=-1.0 size=  338432KiB time=00:01:08.06 bitrate=40731.6kbits/s speed=2.61x elapsed=0:00:26.10
# frame= 2091 fps= 79 q=-1.0 size=  346880KiB time=00:01:09.69 bitrate=40770.0kbits/s speed=2.62x elapsed=0:00:26.60
# frame= 2158 fps= 80 q=-1.0 size=  358144KiB time=00:01:11.93 bitrate=40787.0kbits/s speed=2.65x elapsed=0:00:27.12
# frame= 2208 fps= 80 q=-1.0 size=  366848KiB time=00:01:13.59 bitrate=40832.2kbits/s speed=2.66x elapsed=0:00:27.63
# frame= 2259 fps= 80 q=-1.0 size=  375296KiB time=00:01:15.29 bitrate=40829.4kbits/s speed=2.68x elapsed=0:00:28.14
# frame= 2310 fps= 81 q=-1.0 size=  384000KiB time=00:01:16.99 bitrate=40854.0kbits/s speed=2.69x elapsed=0:00:28.65
# frame= 2361 fps= 81 q=-1.0 size=  392448KiB time=00:01:18.69 bitrate=40850.9kbits/s speed= 2.7x elapsed=0:00:29.16
# frame= 2476 fps= 83 q=-1.0 size=  411648KiB time=00:01:22.53 bitrate=40859.3kbits/s speed=2.78x elapsed=0:00:29.68
# frame= 2494 fps= 83 q=-1.0 size=  414720KiB time=00:01:23.13 bitrate=40867.1kbits/s speed=2.75x elapsed=0:00:30.19
# frame= 2526 fps= 82 q=-1.0 size=  420096KiB time=00:01:24.19 bitrate=40872.5kbits/s speed=2.74x elapsed=0:00:30.70
# frame= 2541 fps= 81 q=-1.0 size=  422400KiB time=00:01:24.69 bitrate=40854.0kbits/s speed=2.71x elapsed=0:00:31.21
# frame= 2579 fps= 81 q=-1.0 size=  428544KiB time=00:01:25.96 bitrate=40837.5kbits/s speed=2.71x elapsed=0:00:31.73
# frame= 1829 fps=116 q=-1.0 size=  304128KiB time=00:01:00.96 bitrate=40865.6kbits/s speed=3.85x elapsed=0:00:15.81
# frame= 1850 fps=113 q=-1.0 size=  307712KiB time=00:01:01.66 bitrate=40877.9kbits/s speed=3.78x elapsed=0:00:16.32
# frame= 1850 fps=110 q=-1.0 size=  307712KiB time=00:01:01.66 bitrate=40877.9kbits/s speed=3.66x elapsed=0:00:16.83
# frame= 1898 fps=109 q=-1.0 size=  315648KiB time=00:01:03.26 bitrate=40871.7kbits/s speed=3.65x elapsed=0:00:17.34
# frame= 1908 fps=107 q=-1.0 size=  317184KiB time=00:01:03.59 bitrate=40855.3kbits/s speed=3.56x elapsed=0:00:17.86
# frame= 1936 fps=105 q=-1.0 size=  322048KiB time=00:01:04.53 bitrate=40881.9kbits/s speed=3.51x elapsed=0:00:18.37
# frame= 1986 fps=105 q=-1.0 size=  330496KiB time=00:01:06.19 bitrate=40898.0kbits/s speed= 3.5x elapsed=0:00:18.88
# frame= 2037 fps=105 q=-1.0 size=  339200KiB time=00:01:07.89 bitrate=40924.2kbits/s speed= 3.5x elapsed=0:00:19.40
# frame= 2066 fps=104 q=-1.0 size=  344064KiB time=00:01:08.86 bitrate=40928.4kbits/s speed=3.46x elapsed=0:00:19.90
# frame= 2087 fps=102 q=-1.0 size=  347648KiB time=00:01:09.56 bitrate=40938.6kbits/s speed=3.41x elapsed=0:00:20.41
# frame= 2128 fps=102 q=-1.0 size=  354304KiB time=00:01:10.96 bitrate=40899.3kbits/s speed=3.39x elapsed=0:00:20.91
# frame= 2161 fps=101 q=-1.0 size=  359680KiB time=00:01:12.03 bitrate=40905.1kbits/s speed=3.36x elapsed=0:00:21.42
# frame= 2214 fps=101 q=-1.0 size=  368384KiB time=00:01:13.79 bitrate=40892.0kbits/s speed=3.37x elapsed=0:00:21.92
# frame= 2421 fps=108 q=-1.0 size=  402432KiB time=00:01:20.69 bitrate=40852.0kbits/s speed= 3.6x elapsed=0:00:22.44
# frame= 2460 fps=107 q=-1.0 size=  408576KiB time=00:01:21.99 bitrate=40818.2kbits/s speed=3.57x elapsed=0:00:22.95
# frame= 2523 fps=108 q=-1.0 size=  419328KiB time=00:01:24.09 bitrate=40846.3kbits/s speed=3.58x elapsed=0:00:23.46
# frame= 2550 fps=106 q=-1.0 size=  423680KiB time=00:01:24.99 bitrate=40833.2kbits/s speed=3.54x elapsed=0:00:23.98
# frame= 2572 fps=105 q=-1.0 size=  427264KiB time=00:01:25.73 bitrate=40826.4kbits/s speed= 3.5x elapsed=0:00:24.49
# frame= 2745 fps=110 q=-1.0 size=  455424KiB time=00:01:31.49 bitrate=40774.5kbits/s speed=3.66x elapsed=0:00:25.00
# frame= 2844 fps=111 q=-1.0 size=  471552KiB time=00:01:34.79 bitrate=40748.9kbits/s speed=3.71x elapsed=0:00:25.52
# frame= 2851 fps=110 q=-1.0 size=  472576KiB time=00:01:35.03 bitrate=40737.1kbits/s speed=3.65x elapsed=0:00:26.03
# frame= 2858 fps=108 q=-1.0 size=  474112KiB time=00:01:35.26 bitrate=40769.4kbits/s speed=3.59x elapsed=0:00:26.53
# frame= 2880 fps=106 q=-1.0 size=  477184KiB time=00:01:35.99 bitrate=40720.1kbits/s speed=3.55x elapsed=0:00:27.05
# frame= 2935 fps=106 q=-1.0 size=  486144KiB time=00:01:37.83 bitrate=40707.3kbits/s speed=3.55x elapsed=0:00:27.56
# frame= 3277 fps=117 q=-1.0 size=  542464KiB time=00:01:49.23 bitrate=40682.7kbits/s speed=3.89x elapsed=0:00:28.07
# frame= 3357 fps=117 q=-1.0 size=  555264KiB time=00:01:51.89 bitrate=40650.3kbits/s speed=3.91x elapsed=0:00:28.59
# frame= 3369 fps=116 q=-1.0 size=  557568KiB time=00:01:52.29 bitrate=40673.6kbits/s speed=3.86x elapsed=0:00:29.10
# frame= 3379 fps=114 q=-1.0 size=  559104KiB time=00:01:52.63 bitrate=40664.9kbits/s speed= 3.8x elapsed=0:00:29.60
# frame= 3501 fps=116 q=-1.0 size=  578816KiB time=00:01:56.69 bitrate=40631.6kbits/s speed=3.88x elapsed=0:00:30.10
# frame= 3511 fps=115 q=-1.0 size=  580608KiB time=00:01:57.03 bitrate=40641.3kbits/s speed=3.82x elapsed=0:00:30.60
# frame= 3511 fps=113 q=-1.0 size=  580608KiB time=00:01:57.03 bitrate=40641.3kbits/s speed=3.76x elapsed=0:00:31.12
# frame= 3546 fps=112 q=-1.0 size=  586496KiB time=00:01:58.19 bitrate=40648.3kbits/s speed=3.74x elapsed=0:00:31.63
# [out#0/mp4 @ 00000253912EEC40] video:595138KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003763%
# frame= 3600 fps=112 q=-1.0 Lsize=  595160KiB time=00:01:59.99 bitrate=40630.0kbits/s speed=3.75x elapsed=0:00:32.02
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000002322591A240] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\temp\video_gily_center_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 40493 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 40493 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\video_gily_center_004.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 40493 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame=  157 fps=0.0 q=-1.0 size=   25856KiB time=00:00:05.23 bitrate=40474.2kbits/s speed=10.2x elapsed=0:00:00.51
# frame=  165 fps=162 q=-1.0 size=   27136KiB time=00:00:05.49 bitrate=40418.3kbits/s speed=5.42x elapsed=0:00:01.01
# frame=  212 fps=138 q=-1.0 size=   34816KiB time=00:00:07.13 bitrate=39983.5kbits/s speed=4.66x elapsed=0:00:01.53
# frame=  300 fps=147 q=-1.0 size=   49408KiB time=00:00:09.99 bitrate=40475.5kbits/s speed=4.89x elapsed=0:00:02.04
# frame=  309 fps=121 q=-1.0 size=   51456KiB time=00:00:10.29 bitrate=40925.5kbits/s speed=4.02x elapsed=0:00:02.56
# frame=  314 fps=103 q=-1.0 size=   52224KiB time=00:00:10.46 bitrate=40874.9kbits/s speed=3.42x elapsed=0:00:03.06
# frame=  324 fps= 91 q=-1.0 size=   53760KiB time=00:00:10.79 bitrate=40778.4kbits/s speed=3.03x elapsed=0:00:03.56
# frame=  330 fps= 81 q=-1.0 size=   54528KiB time=00:00:10.99 bitrate=40608.9kbits/s speed=2.71x elapsed=0:00:04.06
# frame=  284 fps=112 q=-1.0 size=   47104KiB time=00:00:09.46 bitrate=40762.0kbits/s speed=3.74x elapsed=0:00:02.52
# frame=  284 fps= 94 q=-1.0 size=   47104KiB time=00:00:09.46 bitrate=40762.0kbits/s speed=3.12x elapsed=0:00:03.03
# frame=  320 fps= 90 q=-1.0 size=   52736KiB time=00:00:10.66 bitrate=40501.7kbits/s speed=3.01x elapsed=0:00:03.54
# frame=  373 fps= 92 q=-1.0 size=   61440KiB time=00:00:12.43 bitrate=40481.7kbits/s speed=3.06x elapsed=0:00:04.05
# frame=  415 fps= 91 q=-1.0 size=   67840KiB time=00:00:13.83 bitrate=40174.8kbits/s speed=3.03x elapsed=0:00:04.57
# frame=  486 fps= 96 q=-1.0 size=   79360KiB time=00:00:16.19 bitrate=40131.1kbits/s speed=3.19x elapsed=0:00:05.08
# frame=  671 fps=120 q=-1.0 size=  109056KiB time=00:00:22.36 bitrate=39943.2kbits/s speed=   4x elapsed=0:00:05.59
# frame=  977 fps=160 q=-1.0 size=  157440KiB time=00:00:32.56 bitrate=39603.7kbits/s speed=5.33x elapsed=0:00:06.10
# frame= 1050 fps=159 q=-1.0 size=  169216KiB time=00:00:34.99 bitrate=39606.6kbits/s speed=5.29x elapsed=0:00:06.61
# frame= 1072 fps=151 q=-1.0 size=  173056KiB time=00:00:35.73 bitrate=39674.1kbits/s speed=5.02x elapsed=0:00:07.12
# frame= 1087 fps=143 q=-1.0 size=  175616KiB time=00:00:36.23 bitrate=39705.5kbits/s speed=4.75x elapsed=0:00:07.62
# frame= 1165 fps=143 q=-1.0 size=  187904KiB time=00:00:38.83 bitrate=39639.3kbits/s speed=4.78x elapsed=0:00:08.12
# frame= 1241 fps=144 q=-1.0 size=  200192KiB time=00:00:41.36 bitrate=39645.2kbits/s speed= 4.8x elapsed=0:00:08.62
# frame= 1279 fps=140 q=-1.0 size=  206336KiB time=00:00:42.63 bitrate=39647.9kbits/s speed=4.67x elapsed=0:00:09.12
# frame= 1335 fps=139 q=-1.0 size=  215552KiB time=00:00:44.49 bitrate=39681.3kbits/s speed=4.62x elapsed=0:00:09.62
# frame= 1408 fps=139 q=-1.0 size=  226816KiB time=00:00:46.93 bitrate=39590.1kbits/s speed=4.63x elapsed=0:00:10.14
# frame= 1530 fps=144 q=-1.0 size=  246528KiB time=00:00:50.99 bitrate=39599.6kbits/s speed=4.79x elapsed=0:00:10.65
# frame= 1658 fps=148 q=-1.0 size=  267264KiB time=00:00:55.26 bitrate=39616.1kbits/s speed=4.95x elapsed=0:00:11.17
# frame= 1886 fps=161 q=-1.0 size=  304128KiB time=00:01:02.86 bitrate=39630.6kbits/s speed=5.38x elapsed=0:00:11.68
# frame= 2001 fps=164 q=-1.0 size=  322816KiB time=00:01:06.69 bitrate=39648.2kbits/s speed=5.47x elapsed=0:00:12.19
# frame= 2435 fps=192 q=-1.0 size=  392960KiB time=00:01:21.43 bitrate=39531.2kbits/s speed=6.41x elapsed=0:00:12.69
# frame= 2591 fps=196 q=-1.0 size=  418560KiB time=00:01:26.36 bitrate=39701.4kbits/s speed=6.54x elapsed=0:00:13.21
# frame= 2605 fps=190 q=-1.0 size=  420608KiB time=00:01:26.83 bitrate=39681.3kbits/s speed=6.33x elapsed=0:00:13.72
# frame= 2617 fps=184 q=-1.0 size=  422656KiB time=00:01:27.23 bitrate=39691.6kbits/s speed=6.13x elapsed=0:00:14.23
# frame= 2623 fps=178 q=-1.0 size=  423680KiB time=00:01:27.43 bitrate=39696.8kbits/s speed=5.93x elapsed=0:00:14.74
# frame= 2637 fps=173 q=-1.0 size=  425472KiB time=00:01:27.89 bitrate=39653.0kbits/s speed=5.76x elapsed=0:00:15.25
# frame= 2670 fps=169 q=-1.0 size=  430848KiB time=00:01:28.99 bitrate=39657.8kbits/s speed=5.65x elapsed=0:00:15.76
# frame= 2748 fps=169 q=-1.0 size=  443648KiB time=00:01:31.59 bitrate=39676.9kbits/s speed=5.63x elapsed=0:00:16.26
# frame= 2750 fps=164 q=-1.0 size=  443904KiB time=00:01:31.66 bitrate=39670.9kbits/s speed=5.47x elapsed=0:00:16.76
# frame= 2761 fps=160 q=-1.0 size=  445696KiB time=00:01:32.03 bitrate=39672.3kbits/s speed=5.33x elapsed=0:00:17.27
# frame= 2818 fps=158 q=-1.0 size=  454912KiB time=00:01:33.93 bitrate=39673.6kbits/s speed=5.28x elapsed=0:00:17.79
# frame= 2852 fps=156 q=-1.0 size=  460800KiB time=00:01:35.06 bitrate=39708.0kbits/s speed=5.19x elapsed=0:00:18.30
# frame= 3052 fps=162 q=-1.0 size=  492544KiB time=00:01:41.73 bitrate=39662.1kbits/s speed=5.41x elapsed=0:00:18.80
# frame= 3403 fps=176 q=-1.0 size=  549120KiB time=00:01:53.43 bitrate=39657.1kbits/s speed=5.87x elapsed=0:00:19.32
# frame= 3555 fps=179 q=-1.0 size=  573440KiB time=00:01:58.49 bitrate=39642.8kbits/s speed=5.97x elapsed=0:00:19.83
# [out#0/mp4 @ 0000028D0F20F440] video:580604KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003806%
# frame= 3600 fps=177 q=-1.0 Lsize=  580626KiB time=00:01:59.99 bitrate=39637.8kbits/s speed=5.92x elapsed=0:00:20.28
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001E4ABE7DF40] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\temp\video_gily_center_029.txt':
#   Duration: N/A, start: 0.000000, bitrate: 38918 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 38918 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_439\concatenated_data_cam_mic_sync\video_gily_center_029.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 38918 kb/s, 30 fps, 30 tbr, 1000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Press [q] to stop, [?] for help
# frame=   14 fps=0.0 q=-1.0 size=    2304KiB time=00:00:00.46 bitrate=40446.3kbits/s speed=0.913x elapsed=0:00:00.51
# frame=   42 fps= 41 q=-1.0 size=    6656KiB time=00:00:01.39 bitrate=38947.8kbits/s speed=1.36x elapsed=0:00:01.02
# frame=  234 fps=152 q=-1.0 size=   36864KiB time=00:00:07.79 bitrate=38717.1kbits/s speed=5.06x elapsed=0:00:01.54
# frame=  234 fps=115 q=-1.0 size=   36864KiB time=00:00:07.79 bitrate=38717.1kbits/s speed=3.82x elapsed=0:00:02.04
# frame=  511 fps=200 q=-1.0 size=   80896KiB time=00:00:17.29 bitrate=38306.8kbits/s speed=6.77x elapsed=0:00:02.55
# frame=  739 fps=241 q=-1.0 size=  117248KiB time=00:00:24.63 bitrate=38992.1kbits/s speed=8.02x elapsed=0:00:03.07
# frame=  871 fps=243 q=-1.0 size=  137728KiB time=00:00:29.03 bitrate=38861.5kbits/s speed= 8.1x elapsed=0:00:03.58
# frame= 1258 fps=307 q=-1.0 size=  199936KiB time=00:00:41.93 bitrate=39059.4kbits/s speed=10.2x elapsed=0:00:04.09
# frame= 1657 fps=359 q=-1.0 size=  263168KiB time=00:00:55.23 bitrate=39032.5kbits/s speed=  12x elapsed=0:00:04.61
# frame= 1706 fps=333 q=-1.0 size=  270592KiB time=00:00:56.86 bitrate=38980.9kbits/s speed=11.1x elapsed=0:00:05.12
# frame= 1791 fps=318 q=-1.0 size=  284416KiB time=00:00:59.69 bitrate=39027.8kbits/s speed=10.6x elapsed=0:00:05.63
# frame= 1901 fps=309 q=-1.0 size=  301824KiB time=00:01:03.36 bitrate=39020.0kbits/s speed=10.3x elapsed=0:00:06.15
# frame= 2124 fps=319 q=-1.0 size=  336896KiB time=00:01:10.79 bitrate=38981.4kbits/s speed=10.6x elapsed=0:00:06.66
# frame= 2300 fps=320 q=-1.0 size=  364544KiB time=00:01:16.73 bitrate=38918.9kbits/s speed=10.7x elapsed=0:00:07.17
# frame= 2579 fps=335 q=-1.0 size=  408576KiB time=00:01:25.96 bitrate=38934.7kbits/s speed=11.2x elapsed=0:00:07.69
# frame= 2580 fps=314 q=-1.0 size=  408832KiB time=00:01:25.99 bitrate=38944.0kbits/s speed=10.5x elapsed=0:00:08.20
# frame= 2599 fps=298 q=-1.0 size=  411904KiB time=00:01:26.63 bitrate=38949.8kbits/s speed=9.93x elapsed=0:00:08.72
# frame= 2609 fps=282 q=-1.0 size=  413440KiB time=00:01:26.96 bitrate=38945.2kbits/s speed=9.42x elapsed=0:00:09.23
# frame= 2627 fps=269 q=-1.0 size=  416512KiB time=00:01:27.56 bitrate=38965.7kbits/s speed=8.98x elapsed=0:00:09.75
# frame= 2630 fps=256 q=-1.0 size=  416768KiB time=00:01:27.66 bitrate=38945.2kbits/s speed=8.54x elapsed=0:00:10.26
# frame= 2641 fps=245 q=-1.0 size=  418304KiB time=00:01:28.03 bitrate=38925.9kbits/s speed=8.18x elapsed=0:00:10.76
# frame= 2667 fps=237 q=-1.0 size=  422400KiB time=00:01:28.89 bitrate=38923.9kbits/s speed=7.89x elapsed=0:00:11.26
# frame= 2682 fps=228 q=-1.0 size=  425216KiB time=00:01:29.39 bitrate=38964.3kbits/s speed=7.59x elapsed=0:00:11.77
# frame= 2693 fps=219 q=-1.0 size=  426752KiB time=00:01:29.76 bitrate=38945.3kbits/s speed= 7.3x elapsed=0:00:12.29
# frame= 2700 fps=211 q=-1.0 size=  427520KiB time=00:01:29.99 bitrate=38914.2kbits/s speed=7.03x elapsed=0:00:12.80
# frame= 2700 fps=203 q=-1.0 size=  427520KiB time=00:01:29.99 bitrate=38914.2kbits/s speed=6.76x elapsed=0:00:13.32
# frame= 2719 fps=197 q=-1.0 size=  430848KiB time=00:01:30.63 bitrate=38943.1kbits/s speed=6.55x elapsed=0:00:13.83
# frame= 2731 fps=190 q=-1.0 size=  432384KiB time=00:01:31.03 bitrate=38910.2kbits/s speed=6.35x elapsed=0:00:14.34
# frame= 2747 fps=185 q=-1.0 size=  435200KiB time=00:01:31.56 bitrate=38935.5kbits/s speed=6.16x elapsed=0:00:14.85
# frame= 2765 fps=180 q=-1.0 size=  438528KiB time=00:01:32.16 bitrate=38977.8kbits/s speed=   6x elapsed=0:00:15.37
# frame= 2784 fps=175 q=-1.0 size=  441344KiB time=00:01:32.79 bitrate=38960.4kbits/s speed=5.84x elapsed=0:00:15.88
# frame= 2800 fps=171 q=-1.0 size=  444160KiB time=00:01:33.33 bitrate=38985.0kbits/s speed=5.69x elapsed=0:00:16.39
# frame= 2814 fps=166 q=-1.0 size=  445952KiB time=00:01:33.79 bitrate=38947.5kbits/s speed=5.55x elapsed=0:00:16.90
# frame= 2843 fps=163 q=-1.0 size=  450560KiB time=00:01:34.76 bitrate=38948.6kbits/s speed=5.44x elapsed=0:00:17.42
# frame= 2881 fps=161 q=-1.0 size=  456448KiB time=00:01:36.03 bitrate=38937.1kbits/s speed=5.35x elapsed=0:00:17.93
# frame= 2922 fps=158 q=-1.0 size=  463104KiB time=00:01:37.39 bitrate=38950.6kbits/s speed=5.28x elapsed=0:00:18.45
# [out#0/mp4 @ 000001E4ABE6FD00] video:498828KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003936%
# frame= 3150 fps=166 q=-1.0 Lsize=  498847KiB time=00:01:44.99 bitrate=38920.0kbits/s speed=5.54x elapsed=0:00:18.95

# %% [markdown]
# ## Testing sync

# %%
# import warnings
# import math

# %%
# # Redoing the files that didn't get written
# channel_txt_search = path_concat + "*channel_*.txt"
# video_txt_search = path_concat + "*video_*.txt"

# channel_txt_filenames = glob.glob(channel_txt_search)
# video_txt_filenames = glob.glob(video_txt_search)

# channel_txt_filenames.sort(key=natural_keys)
# video_txt_filenames.sort(key=natural_keys)

# upper_no_audio_files = math.ceil(len(channel_txt_filenames)/no_channels)
# upper_no_video_files = math.ceil(len(video_txt_filenames)/len(camera_names))
# print(f"Number of audio files: {upper_no_audio_files}")
# print(f"Number of video files: {upper_no_video_files}")



# # For channel txt files
# prev_ch_idx_nos = 0
# prev_ch_nos = 0

# # if not(len(channel_txt_filenames)%no_channels > (no_channels-1)):
# #     raise Exception(f"Channel txt files are missing re-run code")


# # First test - no of indices per channel is the same
# if len(channel_txt_filenames)%no_channels > 0:
#     warnings.warn("The length of the audio channel text files do not match")
#     print("Testing each channels txt files")

#     counter = 0

#     for name in channel_txt_filenames:
#         vals = name.split("\\")[-1].split('_')
#         channel_ = int(vals[1])
#         index_ = int(vals[2].split(".")[0])

#         if channel_ - prev_ch_nos == 1:
#                 prev_ch_nos = channel_
#                 prev_ch_idx_nos = 0
#                 counter = 0
#         else:
#             raise Exception(f"Missing channel {prev_ch_nos+1} - need to rerun code")

#         if channel_ - prev_ch_nos == 0:
#             if counter == 0:
#                 counter = 1
#                 if  index_ != prev_ch_idx_nos:
#                     raise Exception(f"Missing channel {prev_ch_nos} index {prev_ch_idx_nos} - need to rerun code")
                
#             if prev_ch_idx_nos - index_ > 1:
#                     no_missing_files =  prev_ch_idx_nos - index_
#                     raise Exception(f"There are {no_missing_files} text files in channel {channel_} between {prev_ch_idx_nos} and {index_} - need to rerun code") 

            
#             prev_ch_idx_nos+=1

        
#         temp = file.split('\\')[-1].split(".")[0]
#         full_path_txt = path_concat+temp+".txt"
#         full_path_txt = full_path_txt.replace("/","\\")
#         full_path_wav = path_final+name+".wav"
#         full_path_wav = full_path_wav.replace("/","\\")
#         if  os.path.exists(full_path_wav):
#             continue
#         else:
#             warnings.warn(f"File {temp}.wav doesn't exist - trying to rerun")
#             !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
#             if not(os.path.exists(full_path_wav)):
#                    raise Exception("Unable to create file from txt, re run concat")
        
    

# # For video txt files 
# prev_vid_idx_nos = 0
# camera_names.sort(key=natural_keys)
# prev_vid_name = camera_names[0]


# # if not(len(video_txt_filenames)/len(camera_names) > len(camera_names)-1):
# #     raise Exception(f"Video txt files are missing re-run code")

# # First test - no of indices per video is the same
# if len(video_txt_filenames)//len(camera_names) != len(channel_txt_filenames)//no_channels:
#     warnings.warn("The length of the video text files per camera do not match")
#     print("Testing each cameras txt files")

#     counter = 0

#     for name in video_txt_filenames:

#         vals = name.split("\\")[-1].split('_')
#         video_ = vals[1]
#         index_ = int(vals[2].split(".")[0])

#         if video_ != prev_vid_name:
#                 prev_vid_name = video_
#                 prev_vid_idx_nos = 0
#                 counter = 0

#         if video_ == prev_vid_name:
#             if counter == 0:
#                 counter = 1
#                 if  index_ != prev_vid_idx_nos:
#                     raise Exception(f"Missing video {prev_vid_name} index {prev_vid_idx_nos}")
                
#             if prev_vid_idx_nos - index_ > 1:
#                     no_missing_files =  prev_vid_idx_nos - index_
#                     raise Exception(f"There are {no_missing_files} text files in channel {video_} between {prev_vid_idx_nos} and {index_}") 

            
#             prev_ch_idx_nos+=1


#         temp = file.split('\\')[-1].split(".")[0]
#         full_path_txt = path_concat+temp+".txt"
#         full_path_txt = full_path_txt.replace("/","\\")

#         full_path_mp4 = path_final+name+".mp4"
#         full_path_mp4 = full_path_mp4.replace("/","\\")

#         if  os.path.exists(full_path_mp4):
#             continue
#         else:
#             warnings.warn(f"File {temp}.mp4 doesn't exist - trying to rerun")
#             !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_mp4}
#             if not(os.path.exists(full_path_wav)):
#                    raise Exception("Unable to create file from txt, re run concat")
# Out:
# Number of audio files: 51
# Number of video files: 51

# %% [markdown]
# old camera frame rate - 1/0.03338542
#
# new camera frame rate -
