# %% [markdown]
# ### Note: Please ensure that this notebook is run in the daq environment

# %%
import glob
import os
import tqdm
from collections import defaultdict
import re
import numpy as np
import pandas as pd
from scipy.io import wavfile
# from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.video.io.VideoFileClip import VideoFileClip
from datetime import datetime, timedelta
import copy

# %%
def seconds_to_hms(seconds):
    # Calculate hours, minutes, and seconds
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    # Format the time in HH:MM:SS
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}.{int(remainder%1*1000):03}"

# %%
from moviepy.tools import subprocess_call
from moviepy.config import get_setting

def ffmpeg_extract_subclip(filename, t1, t2, targetname=None):
    """ Makes a new video file playing video file ``filename`` between
    the times ``t1`` and ``t2``. """
    # !ffmpeg -i {filename} -ss {seconds_to_hms(t1)} -to {seconds_to_hms(t2)} -c copy {targetname}

# %%
experiment_no = 384
no_channels = 13
camera_fps = 30
# camera_corrected_sample_time = 0.03338542
file_length = 120 # in seconds (120 sec - 2 mins)
sampling_rate = 125000
# nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
video_folder = "D:/big_setup/experiment_{}/videos/".format(experiment_no)

# %%
# Deleting the trunc files if it is already present
trunc_files = glob.glob(nidaq_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i) 

trunc_files = glob.glob(video_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i)

# %%
nidaq_files = glob.glob(nidaq_folder+"*")
video_files = glob.glob(video_folder+"*")

# %%
# Creating separate folders for the concatenated data
path_concat = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/temp/".format(experiment_no)

try:
    os.makedirs(path_concat)
except:
    pass

# %%
path_final = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/".format(experiment_no)

# %%
# Functions to sort file names correctly
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
nidaq_files.sort(key=natural_keys)
video_files.sort(key=natural_keys)

# %%
nidaq_files = [i.replace("\\",'/') for i in nidaq_files]
video_files = [i.replace("\\",'/') for i in video_files]

# %% [markdown]
# ### For Videos

# %%
# Getting the camera names
temp_cam_name = []
for i in video_files:
    temp_cam_name.append(i.split("/")[-1].split("-")[0])
camera_names = list(set(temp_cam_name))
print(camera_names)
# Out:
# ['gily_center']

# %%
# Creating a dictionary of all videos of a single camera
video_by_camera = defaultdict(lambda:[])
for idx,name in enumerate(temp_cam_name):
    video_by_camera[name].append(video_files[idx])

# %%
cam_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")

# %%
file_breaks  = np.arange(0,cam_clk_data.tail(1).index[0]/camera_fps,file_length)
last_break = cam_clk_data.tail(1).index[0]
timestamp_idx = []
for val in file_breaks:
    timestamp_idx.append((np.abs(cam_clk_data[f'concat_{camera_names[0]}_time_from_vid_start'] - val)).argmin())

# %%
if timestamp_idx[-1] != last_break:
    timestamp_idx.append(last_break)

# %% [markdown]
# ### Assumes
# - 5 min original videos and shorter concatenated videos
# - concatenation starts from 0.0 of first video for each camera
# - all videos are recorded properly

# %%
vals = []
for cam in camera_names:
    file_concat_index = 0 
    no_videos = len(video_by_camera[cam])
    id = 0
    
    temp = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_file_name'].split('\\')
    prev_vid_name = temp[0]+'/'+temp[1]
    prev_break_time = cam_clk_data.iloc[timestamp_idx[0]][f'{cam}_time_from_vid_start']
    prev_file_break = timestamp_idx[0]

    for file_break in timestamp_idx[1:]:

            #--------------------------------------- edited -----------------------------------------------

            temp = cam_clk_data.iloc[file_break][f'{cam}_file_name'].split('\\')
            vid_name = temp[0]+'/'+temp[1]
            break_time = cam_clk_data.iloc[file_break][f'{cam}_time_from_vid_start']
            str_1 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"video_{cam}_{str_1}.txt"

            if prev_vid_name != vid_name: # when we reach the end of a saved file and start a new one

                with VideoFileClip(prev_vid_name) as video:
                    end_time = video.duration
                    
                    vals.append([end_time,prev_break_time])
                    if end_time-prev_break_time > 1:
                        tmp = cam_clk_data.iloc[prev_file_break][f'{cam}_file_name'].split('\\')
                        target_file = tmp[0]+"/"+tmp[1].split(".")[0]+f"_trunc_{id}.mp4"     
                        # print(prev_vid_name)
                        # print(target_file) 
                        ffmpeg_extract_subclip(prev_vid_name, prev_break_time, end_time, targetname=target_file)
                
                        f = open(filename_txt, 'a')
                        f.write("file \'{}\'\n".format(target_file))
                        f.close()
                    
                    prev_break_time = 0.0
                    id = 0
                    
            target_file = temp[0]+"/"+temp[1].split(".")[0]+f"_trunc_{id}.mp4"
            # print(vid_name, target_file)
            ffmpeg_extract_subclip(vid_name, prev_break_time, break_time, targetname=target_file)

            f = open(filename_txt, 'a')
            f.write("file \'{}\'\n".format(target_file))
            f.close()
            
            prev_break_time = copy.deepcopy(break_time)
            id+=1
            file_concat_index+=1
            prev_vid_name = copy.deepcopy(vid_name)
            prev_file_break = copy.deepcopy(file_break)
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T124949-125450.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4542 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4539 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T124949-125450_trunc_0.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4539 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000018C8AD56040] video:66344KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024564%
# frame= 3601 fps=0.0 q=-1.0 Lsize=   66360KiB time=00:02:00.26 bitrate=4520.2kbits/s speed= 707x elapsed=0:00:00.17
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T124949-125450.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4542 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4539 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T124949-125450_trunc_1.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4539 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 000002039A6B2C40] video:65927KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024459%
# frame= 3571 fps=0.0 q=-1.0 Lsize=   65943KiB time=00:04:00.23 bitrate=2248.7kbits/s speed=2.45e+03x elapsed=0:00:00.09
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T124949-125450.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4542 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4539 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T124949-125450_trunc_2.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4539 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 000001FC261572C0] video:33598KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.025497%
# frame= 1800 fps=0.0 q=-1.0 Lsize=   33607KiB time=00:05:00.99 bitrate= 914.7kbits/s speed=2.88e+03x elapsed=0:00:00.10
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4518 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951_trunc_0.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 00000291ABAC5B40] video:32316KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.025988%
# frame= 1771 fps=0.0 q=-1.0 Lsize=   32325KiB time=00:00:59.29 bitrate=4465.5kbits/s speed=1.5e+03x elapsed=0:00:00.03
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4518 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951_trunc_1.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 00000196B4783840] video:65770KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024523%
# frame= 3572 fps=0.0 q=-1.0 Lsize=   65786KiB time=00:02:59.06 bitrate=3009.6kbits/s speed=1.55e+03x elapsed=0:00:00.11
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4518 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951_trunc_2.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 000001A17C851680] video:65886KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024367%
# frame= 3571 fps=0.0 q=-1.0 Lsize=   65902KiB time=00:04:59.29 bitrate=1803.8kbits/s speed=2.57e+03x elapsed=0:00:00.11
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 4518 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T125450-125951_trunc_3.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4515 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000028E43EF5A40] video:539KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.174687%
# frame=   30 fps=0.0 q=-1.0 Lsize=     540KiB time=00:05:00.99 bitrate=  14.7kbits/s speed=3.86e+03x elapsed=0:00:00.07
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T125951-130322.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:03:32.00, start: 0.000000, bitrate: 4565 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4581 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T125951-130322_trunc_0.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4581 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 00000180C79C5940] video:65482KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024488%
# frame= 3541 fps=0.0 q=-1.0 Lsize=   65498KiB time=00:01:58.06 bitrate=4544.6kbits/s speed=1.75e+03x elapsed=0:00:00.06
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_384/videos/gily_center-20251117T125951-130322.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:03:32.00, start: 0.000000, bitrate: 4565 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4581 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:/big_setup/experiment_384/videos/gily_center-20251117T125951-130322_trunc_1.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4581 kb/s, 30 fps, 30 tbr, 10000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 000001A17C8A4A40] video:51453KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024393%
# frame= 2730 fps=0.0 q=-1.0 Lsize=   51465KiB time=00:03:30.03 bitrate=2007.3kbits/s speed=2.23e+03x elapsed=0:00:00.09

# %% [markdown]
# ### For NIDAQ

# %%
# Reading the timestamps data for the camera clock channel 
audio_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")
audio_start_rec_idx = int(cam_clk_data["clk_ch_file_name"][0].split("\\")[1].split("_")[2])
audio_stop_rec_idx = int(cam_clk_data["clk_ch_file_name"].iloc[-1].split("\\")[1].split("_")[2])
start_sample_index =  int(cam_clk_data["clk_ch_sample_idx"][0])
end_sample_index =  int(cam_clk_data["clk_ch_sample_idx"].iloc[-1])

# %%
# Concatenating the microphone channels
for ch_no in range(no_channels):
    file_concat_index = 0 
    id = 0

    prev_ch_name = "_".join(audio_clk_data.iloc[timestamp_idx[0]][f'clk_ch_file_name'].split("_")[:-1])+f"_{ch_no}.wav"
    prev_break_idx = audio_clk_data.iloc[timestamp_idx[0]][f'clk_ch_sample_idx']


    for file_break in tqdm.tqdm(timestamp_idx[1:]):

            #--------------------------------------- edited -----------------------------------------------

            ch_name = "_".join(audio_clk_data.iloc[file_break][f'clk_ch_file_name'].split("_")[:-1])+f"_{ch_no}.wav"
            break_idx = audio_clk_data.iloc[file_break][f'clk_ch_sample_idx']
            str_1 = "%02d"%(ch_no)
            str_2 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"channel_{str_1}_file_{str_2}.txt"

            if prev_ch_name != ch_name: # when we reach the end of a saved file and start a new one
                    if prev_break_idx < (sampling_rate*300)-1000:
                        target_file = prev_ch_name.split(".")[0]+f"_trunc_{id}.wav"   

                        # Loading the file
                        sampling_rate,ch = wavfile.read(prev_ch_name)
                        ch = ch[prev_break_idx:]
                        
                        wavfile.write(target_file,sampling_rate,ch)
                
                        f = open(filename_txt, 'a')
                        f.write("file \'{}\'\n".format(target_file))
                        f.close()
                    
                    prev_break_idx = 0
                    id = 0
                    
            target_file = ch_name.split(".")[0]+f"_trunc_{id}.wav"

            # Loading the file
            sampling_rate,ch = wavfile.read(ch_name)
            ch = ch[prev_break_idx:break_idx]
                        
            wavfile.write(target_file,sampling_rate,ch)
                
            f = open(filename_txt, 'a')
            f.write("file \'{}\'\n".format(target_file))
            f.close()
                    

            
            prev_break_idx = copy.deepcopy(break_idx)
            id+=1
            file_concat_index+=1
            prev_ch_name = copy.deepcopy(ch_name)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# 100%|██████████| 7/7 [00:02<00:00,  3.01it/s]
# 100%|██████████| 7/7 [00:02<00:00,  2.96it/s]
# 100%|██████████| 7/7 [00:02<00:00,  3.24it/s]
# 100%|██████████| 7/7 [00:02<00:00,  2.41it/s]
# 100%|██████████| 7/7 [00:03<00:00,  1.98it/s]
# 100%|██████████| 7/7 [00:02<00:00,  3.17it/s]
# 100%|██████████| 7/7 [00:02<00:00,  2.78it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.50it/s]
# 100%|██████████| 7/7 [00:03<00:00,  2.19it/s]
# 100%|██████████| 7/7 [00:02<00:00,  3.50it/s]
# 100%|██████████| 7/7 [00:02<00:00,  2.91it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.70it/s]
# 100%|██████████| 7/7 [00:03<00:00,  2.12it/s]

# %% [markdown]
# ## Steps done via code in the below cell
# - open anaconda prompt
# - Enter the following commands:
#     - For video concatenation:
#         - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\video_e3v83b3.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\e3v83b3_ffmpeg.mp4```
#     - For NIDAQ concatenation:
#         - - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0_ffmpeg.wav```

# %%
no_audio_files = int(len(glob.glob(path_concat + "*channel_*.txt"))/no_channels)
no_video_files = int(len(glob.glob(path_concat + "*video_*.txt"))/len(camera_names))

# %%
timestamp_record_data = cam_clk_data.iloc[timestamp_idx]
time_starts = []
time_ends = []
column_names = [i for i in timestamp_record_data.columns if i.endswith("file_name") and not(i.startswith('clk'))]

starting_timestamp = datetime.strptime(timestamp_record_data[column_names[0]][0].split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S')

# for camera_file in column_names:
#     for file_name in timestamp_record_data[camera_file]:
#         time_starts.append(datetime.strptime(file_name.split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S'))
#         time_ends.append(time_starts[-1] + timedelta(minutes=file_length/60))

# %%
# if no_audio_files != no_video_files:
#     raise Exception("Number of audio and video files don't match")
# else:
matched_csv = []
timestamp_write = starting_timestamp
f = open(path_final+"README.txt", 'w')
f.write("The files that are synced are as follows:\n")
f.write("Video file names - corresponding audio file names - timestamp range of file \n")
for i in range(no_audio_files):
    temp_0 = []
    temp_1 = []
    temp_2 = [timestamp_write.strftime("%Y-%m-%d %H:%M:%S"),(timestamp_write + timedelta(minutes=file_length/60)).strftime("%Y-%m-%d %H:%M:%S")]
    timestamp_write += timedelta(minutes=file_length/60)
    for j in range(no_channels):
        var_1 = "%03d"%(i)
        var_2 = "%02d"%(j)
        temp_0.append(f"channel_{var_2}_file_{var_1}")
    for j in camera_names:
        var_1 = "%03d"%(i)
        temp_1.append(f"video_{j}_{var_1}")
    f.write(f"[{', '.join(temp_1)}] - [{', '.join(temp_0)}] - [{', '.join(temp_2)}]\n")
    matched_csv.append([temp_1,temp_0,temp_2])
pd.DataFrame(matched_csv,columns=["video","audio","timestamp"]).to_csv(path_final+"sync.csv", index = False)
f.close()

# %%
filename_txt = path_concat + "*.txt"
txt_files = glob.glob(filename_txt)
video_files = []
audio_files = []

for file in txt_files:
    name = file.split('\\')[-1].split(".")[0]
    full_path_txt = path_concat+name+".txt"
    full_path_txt = full_path_txt.replace("/","\\")
    if name[0] == "c":
        full_path_wav = path_final+name+".wav"
        full_path_wav = full_path_wav.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
        # -rf64 auto
    else:
        full_path_mp4 = path_final+name+".mp4"
        full_path_mp4 = full_path_mp4.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy {full_path_mp4}
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000002B4CCC5EA00] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_000.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000002B4CCC14500] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.64e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001F0E684E600] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_001.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001F0E49C54C0] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.7e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001BEE0DE80C0] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_002.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_002.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001BEE0E04D40] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.35e+03x elapsed=0:00:00.05
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 0000019395321580] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_003.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_003.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0000019391453200] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.38e+03x elapsed=0:00:00.05
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000002C088F3B440] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_004.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000002C088EE3D40] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.56e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001EC5B6885C0] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_005.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_005.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001EC5A8932C0] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.82e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000002351B732540] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_00_file_006.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_00_file_006.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000002351B6E4980] video:0KiB audio:44901KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000248%
# size=   44902KiB time=00:01:31.95 bitrate=4000.0kbits/s speed=2.31e+03x elapsed=0:00:00.03
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001A414DA6080] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_000.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001A414D56300] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.93e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 00000229084B1580] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_001.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 00000229084F4AC0] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.78e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001F80F53EB80] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_002.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_002.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001F80F503300] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.56e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001C29B57A880] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_003.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_003.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001C29B542F40] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=3.55e+03x elapsed=0:00:00.03
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 00000217D9A11900] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_004.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 00000217D99B3200] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed= 333x elapsed=0:00:00.36
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000002E53E418540] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_005.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_005.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000002E53A525400] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.45e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 000001586C8AE100] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_01_file_006.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_01_file_006.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 000001586C863800] video:0KiB audio:44901KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000248%
# size=   44902KiB time=00:01:31.95 bitrate=4000.0kbits/s speed=2.77e+03x elapsed=0:00:00.03
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 00000199D88B4580] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_000.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 00000199D8863040] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.83e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 00000166355DAF00] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_001.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0000016635531D80] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.68e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 0000023A7F8D0C00] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_002.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_002.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0000023A7DAF2180] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.61e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 0000023474E06DC0] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_003.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_003.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0000023474E23D80] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.92e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 0000021CBC9DC8C0] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_004.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0000021CBC932780] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=3.04e+03x elapsed=0:00:00.03
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 00000127EAB2BE40] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_005.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_005.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 00000127EAAD5700] video:0KiB audio:58586KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000190%
# size=   58586KiB time=00:01:59.98 bitrate=4000.0kbits/s speed=2.61e+03x elapsed=0:00:00.04
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 0000015499B6A780] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_02_file_006.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_02_file_006.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Press [q] to stop, [?] for help
# [out#0/wav @ 0000015495CC4440] video:0KiB audio:44901KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000248%
# size=   44902KiB time=00:01:31.95 bitrate=4000.0kbits/s speed=2.99e+03x elapsed=0:00:00.03
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [aist#0:0/pcm_f32le @ 00000178F23FACC0] Guessed Channel Layout: mono
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\channel_03_file_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#   Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, wav, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\channel_03_file_000.wav':
#   Metadata:
#     ISFT            : Lavf62.3.100
# ...
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_000.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4527 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000012EF9C2C180] video:66344KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024742%
# frame= 3601 fps=0.0 q=-1.0 Lsize=   66360KiB time=00:02:00.03 bitrate=4529.0kbits/s speed=1.04e+03x elapsed=0:00:00.11
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000265474E8040] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\video_gily_center_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4537 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4537 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_001.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4537 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 00000265474A3500] video:65927KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024619%
# frame= 3571 fps=0.0 q=-1.0 Lsize=   65943KiB time=00:01:59.03 bitrate=4538.3kbits/s speed=1.02e+03x elapsed=0:00:00.11
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001A1F39B43C0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\video_gily_center_002.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4587 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4587 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_002.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4587 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001A1F39B43C0] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 000001A1F7E69380] video:65914KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024695%
# frame= 3571 fps=0.0 q=-1.0 Lsize=   65931KiB time=00:01:59.03 bitrate=4537.5kbits/s speed= 686x elapsed=0:00:00.17
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 00000262BABBC880] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\video_gily_center_003.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4525 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4525 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_003.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4525 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 00000262BAB67D40] video:65770KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024684%
# frame= 3572 fps=0.0 q=-1.0 Lsize=   65786KiB time=00:01:59.06 bitrate=4526.3kbits/s speed= 544x elapsed=0:00:00.21
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000029A7F90ABC0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\video_gily_center_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4534 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4534 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_004.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4534 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000029A7F8C42C0] video:65886KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024528%
# frame= 3571 fps=0.0 q=-1.0 Lsize=   65902KiB time=00:01:59.03 bitrate=4535.5kbits/s speed= 711x elapsed=0:00:00.16
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000016AB2689A40] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\video_gily_center_005.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4414 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4414 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_005.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4414 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000016AB2689A40] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 0000016AB268B380] video:66021KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024566%
# frame= 3571 fps=0.0 q=-1.0 Lsize=   66037KiB time=00:01:59.03 bitrate=4544.8kbits/s speed= 895x elapsed=0:00:00.13
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 21.1.2
#   configuration: --prefix=/d/bld/ffmpeg_1758923948582/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/d/bld/ffmpeg_1758923948582/_build_env/Library/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0000027208C996C0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\temp\video_gily_center_006.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4631 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4631 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to 'D:\big_setup\experiment_384\concatenated_data_cam_mic_sync\video_gily_center_006.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4631 kb/s, 30 fps, 30 tbr, 10000k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0000027208C47440] video:51453KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.024543%
# frame= 2730 fps=0.0 q=-1.0 Lsize=   51465KiB time=00:01:30.99 bitrate=4633.1kbits/s speed= 520x elapsed=0:00:00.17

# %% [markdown]
# ## Testing sync

# %%
# import warnings
# import math

# %%
# # Redoing the files that didn't get written
# channel_txt_search = path_concat + "*channel_*.txt"
# video_txt_search = path_concat + "*video_*.txt"

# channel_txt_filenames = glob.glob(channel_txt_search)
# video_txt_filenames = glob.glob(video_txt_search)

# channel_txt_filenames.sort(key=natural_keys)
# video_txt_filenames.sort(key=natural_keys)

# upper_no_audio_files = math.ceil(len(channel_txt_filenames)/no_channels)
# upper_no_video_files = math.ceil(len(video_txt_filenames)/len(camera_names))
# print(f"Number of audio files: {upper_no_audio_files}")
# print(f"Number of video files: {upper_no_video_files}")



# # For channel txt files
# prev_ch_idx_nos = 0
# prev_ch_nos = 0

# # if not(len(channel_txt_filenames)%no_channels > (no_channels-1)):
# #     raise Exception(f"Channel txt files are missing re-run code")


# # First test - no of indices per channel is the same
# if len(channel_txt_filenames)%no_channels > 0:
#     warnings.warn("The length of the audio channel text files do not match")
#     print("Testing each channels txt files")

#     counter = 0

#     for name in channel_txt_filenames:
#         vals = name.split("\\")[-1].split('_')
#         channel_ = int(vals[1])
#         index_ = int(vals[2].split(".")[0])

#         if channel_ - prev_ch_nos == 1:
#                 prev_ch_nos = channel_
#                 prev_ch_idx_nos = 0
#                 counter = 0
#         else:
#             raise Exception(f"Missing channel {prev_ch_nos+1} - need to rerun code")

#         if channel_ - prev_ch_nos == 0:
#             if counter == 0:
#                 counter = 1
#                 if  index_ != prev_ch_idx_nos:
#                     raise Exception(f"Missing channel {prev_ch_nos} index {prev_ch_idx_nos} - need to rerun code")
                
#             if prev_ch_idx_nos - index_ > 1:
#                     no_missing_files =  prev_ch_idx_nos - index_
#                     raise Exception(f"There are {no_missing_files} text files in channel {channel_} between {prev_ch_idx_nos} and {index_} - need to rerun code") 

            
#             prev_ch_idx_nos+=1

        
#         temp = file.split('\\')[-1].split(".")[0]
#         full_path_txt = path_concat+temp+".txt"
#         full_path_txt = full_path_txt.replace("/","\\")
#         full_path_wav = path_final+name+".wav"
#         full_path_wav = full_path_wav.replace("/","\\")
#         if  os.path.exists(full_path_wav):
#             continue
#         else:
#             warnings.warn(f"File {temp}.wav doesn't exist - trying to rerun")
#             !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
#             if not(os.path.exists(full_path_wav)):
#                    raise Exception("Unable to create file from txt, re run concat")
        
    

# # For video txt files 
# prev_vid_idx_nos = 0
# camera_names.sort(key=natural_keys)
# prev_vid_name = camera_names[0]


# # if not(len(video_txt_filenames)/len(camera_names) > len(camera_names)-1):
# #     raise Exception(f"Video txt files are missing re-run code")

# # First test - no of indices per video is the same
# if len(video_txt_filenames)//len(camera_names) != len(channel_txt_filenames)//no_channels:
#     warnings.warn("The length of the video text files per camera do not match")
#     print("Testing each cameras txt files")

#     counter = 0

#     for name in video_txt_filenames:

#         vals = name.split("\\")[-1].split('_')
#         video_ = vals[1]
#         index_ = int(vals[2].split(".")[0])

#         if video_ != prev_vid_name:
#                 prev_vid_name = video_
#                 prev_vid_idx_nos = 0
#                 counter = 0

#         if video_ == prev_vid_name:
#             if counter == 0:
#                 counter = 1
#                 if  index_ != prev_vid_idx_nos:
#                     raise Exception(f"Missing video {prev_vid_name} index {prev_vid_idx_nos}")
                
#             if prev_vid_idx_nos - index_ > 1:
#                     no_missing_files =  prev_vid_idx_nos - index_
#                     raise Exception(f"There are {no_missing_files} text files in channel {video_} between {prev_vid_idx_nos} and {index_}") 

            
#             prev_ch_idx_nos+=1


#         temp = file.split('\\')[-1].split(".")[0]
#         full_path_txt = path_concat+temp+".txt"
#         full_path_txt = full_path_txt.replace("/","\\")

#         full_path_mp4 = path_final+name+".mp4"
#         full_path_mp4 = full_path_mp4.replace("/","\\")

#         if  os.path.exists(full_path_mp4):
#             continue
#         else:
#             warnings.warn(f"File {temp}.mp4 doesn't exist - trying to rerun")
#             !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_mp4}
#             if not(os.path.exists(full_path_wav)):
#                    raise Exception("Unable to create file from txt, re run concat")
# Out:
# Number of audio files: 51
# Number of video files: 51

# %% [markdown]
# old camera frame rate - 1/0.03338542
#
# new camera frame rate -
